# %%
import pandas as pd
import numpy as np
import nltk
import gensim
import re
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from gensim import corpora
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_excel('hvac_all_issues.xlsx')

# %%
len(df)
# Out:
# 43041

# %%
def combine_columns(df,cols):
    all_docs = []
    for index, row in df.iterrows():
        tempstr = ''
        for col in cols:
            try:
                tempstr += str(row[col]) + ' '
            except:
                print('Column Not Found : ', col)
        all_docs.append(tempstr)
    return all_docs

# %%
issue_text = combine_columns(df, ['Action.Requested', 'General.Comments', 'Task.Comments'])

# %%
issue_text[0:5]
# Out:
# ['Portable Generator Maintenance-Monthly nan nan ',
#  'Roof Drain Quarterly Maintenance nan nan ',
#  'Marcos with SACS called to report the ballrooms are too warm for an event going on until 9pm. Spoke to Don at CP. nan 2017-05-19 - 18290 - Donald Miller-Checked la sala and made adjustments to temperature setpoint.  Followed up, ok - Donald Miller ',
#  'The sink in our lobby area is not working. The sensor turns water on but it does not stay on. nan 2017-05-18 - 23070 - Tim Jowers-pulled it down and cleaned the strainers also reset the sensor that controls the faucet. called the factory to lean how to reset the control to set time of run, not covered in the paperwork. - Tim Jowers ',
#  'Please adjust the temperature in the lab to approx 75 Degrees. They say its tooooo cold. Thank you. nan 2017-05-18 - 18300 - Chad T Ball-Adjusted set point to 75. Damper was found in operator control. Released damper to automatic control. - Chad T Ball ']

# %%
def remove_punctutation(all_docs):
    no_punctuation_docs = []
    for doc in all_docs:
        doc = doc.replace("-", " ")
        no_punctuation_docs.append(re.sub(r'[^\w\s]','',doc))
    return no_punctuation_docs

# %%
def tokenizer(all_docs):
    tokenized_docs = []
    for doc in all_docs:
        tokenized_docs.append(word_tokenize(doc))
    return tokenized_docs

# %%
def lemmatizer(all_docs):
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmatized_docs = []
    for doc in all_docs:
        temp = []
        for token in doc:
            if token.isalpha():
                temp.append(wordnet_lemmatizer.lemmatize(token,"v"))
        lemmatized_docs.append(temp)
    return lemmatized_docs

# %%
def stemmer(all_docs):
    porter_stemmer = PorterStemmer()
    stemmed_docs = []
    for doc in all_docs:
        temp = []
        for token in doc:
            temp.append(porter_stemmer.stem(token))
        stemmed_docs.append(temp)
    return stemmed_docs

# %%
def untokenizer(all_docs):
    untokenized_docs = []
    for doc in all_docs:
        untokenized_docs.append(" ".join(doc))
    return untokenized_docs

# %%
def create_dtm(all_docs,stopwords,ngram):
    vectorizer = CountVectorizer(lowercase=True,min_df=5,ngram_range=(1, ngram),stop_words=stopwords)
    dtm = vectorizer.fit_transform(all_docs)
    return vectorizer,dtm

# %%
def tfidf_transformer(dtm):
    tf_transformer = TfidfTransformer()
    tfidf = tf_transformer.fit_transform(dtm)
    return tf_transformer,tfidf

# %%
#REMOVE PUNCTUATION
punctuation_issues = remove_punctutation(issue_text)

# %%
#Tokenize each issue text
tokenized_issues = tokenizer(punctuation_issues)

# %%
#lemmatize the tokens
lemmatized_issues = lemmatizer(tokenized_issues)

# %%
#Stem the words
stemmed_issues = stemmer(lemmatized_issues)

# %%
#Untokenize the tokens to form sentence again
untokenized_issues = untokenizer(stemmed_issues)

# %%
stop_words = stopwords.words('english')
stop_words.append('nan')

# %%
vectorizer, dtm = create_dtm(untokenized_issues,stop_words,1)

# %%
tf_transformer, tfidf = tfidf_transformer(dtm)

# %%
np.shape(tfidf)
# Out:
# (43041, 4334)

# %%
vectorizer = TfidfVectorizer(stop_words=stop_words, use_idf=True, ngram_range=(1,1))
# tokenize and build vocab
tfidf_matrix = vectorizer.fit_transform(untokenized_issues)

# %%
np.shape(tfidf_matrix)
# Out:
# (43041, 14562)

# %%
tfidf_dense = tfidf_matrix.todense()

# %%
vectorizer.vocabulary_
# Out:
# {'portabl': 9639,
#  'gener': 5252,
#  'mainten': 7584,
#  'monthli': 8148,
#  'roof': 10869,
#  'drain': 3894,
#  'quarterli': 10054,
#  'marco': 7665,
#  'sac': 11075,
#  'call': 1820,
#  'report': 10544,
#  'ballroom': 1001,
#  'warm': 13964,
#  'event': 4459,
#  'go': 5341,
#  'spoke': 12019,
#  'cp': 3040,
#  'donald': 3804,
#  'miller': 8007,
#  'check': 2158,
#  'la': 6986,
#  'sala': 11101,
#  'make': 7593,
#  'adjust': 186,
#  'temperatur': 12691,
#  'setpoint': 11437,
#  'follow': 4960,
#  'ok': 8774,
#  'sink': 11715,
#  'lobbi': 7364,
#  'area': 667,
#  'work': 14318,
#  'sensor': 11376,
#  'turn': 13290,
#  'water': 14005,
#  'stay': 12182,
#  'tim': 12950,
#  'jower': 6688,
#  'pull': 9938,
#  'clean': 2369,
#  'strainer': 12275,
#  'also': 457,
#  'reset': 10621,
#  'control': 2866,
#  'faucet': 4670,
#  'factori': 4592,
#  'lean': 7144,
#  'set': 11431,
#  'time': 12953,
#  'run': 11034,
#  'cover': 3026,
#  'paperwork': 9177,
#  'pleas': 9508,
#  'lab': 6987,
#  'approx': 631,
#  'degre': 3435,
#  'say': 11185,
#  'tooooo': 13078,
#  'cold': 2543,
#  'thank': 12793,
#  'chad': 2082,
#  'ball': 993,
#  'point': 9580,
#  'damper': 3254,
#  'find': 4795,
#  'oper': 8870,
#  'releas': 10403,
#  'automat': 881,
#  'simplex': 11702,
#  'duct': 3976,
#  'detector': 3554,
#  'alarm': 375,
#  'issu': 6454,
#  'thi': 12858,
#  'room': 10881,
#  'david': 3322,
#  'valentin': 13657,
#  'assist': 797,
#  'ron': 10864,
#  'ronald': 10865,
#  'chaffe': 2084,
#  'troubl': 13226,
#  'shoot': 11580,
#  'remov': 10436,
#  'blow': 1406,
#  'dust': 4019,
#  'still': 12231,
#  'replac': 10515,
#  'new': 8490,
#  'servic': 11415,
#  'tech': 12648,
#  'repair': 10473,
#  'test': 12771,
#  'switch': 12502,
#  'print': 9773,
#  'circuit': 2317,
#  'board': 1423,
#  'fan': 4632,
#  'separ': 11381,
#  'watchkeep': 14003,
#  'relay': 10400,
#  'sq': 12054,
#  'light': 7251,
#  'contactor': 2843,
#  'nw': 8650,
#  'park': 9187,
#  'lot': 7433,
#  'cabinet': 1768,
#  'rr': 10990,
#  'updat': 13571,
#  'vehicl': 13741,
#  'number': 8642,
#  'decal': 3377,
#  'gator': 5226,
#  'see': 11344,
#  'attach': 842,
#  'log': 7391,
#  'outdoor': 9003,
#  'hot': 5972,
#  'orient': 8954,
#  'day': 3328,
#  'pm': 9553,
#  'ef': 4117,
#  'facilit': 4584,
#  'ventil': 13760,
#  'cl': 2337,
#  'ii': 6136,
#  'crtyrd': 3126,
#  'tree': 13191,
#  'relamp': 10396,
#  'weed': 14086,
#  'process': 9818,
#  'ada': 141,
#  'door': 3823,
#  'weekli': 14091,
#  'inspect': 6300,
#  'xpm': 14449,
#  'wc': 14052,
#  'adadoor': 142,
#  'properli': 9876,
#  'compressor': 2697,
#  'east': 4059,
#  'side': 11655,
#  'first': 4819,
#  'floor': 4892,
#  'bad': 964,
#  'shape': 11503,
#  'need': 8455,
#  'soon': 11908,
#  'air': 322,
#  'purchas': 10000,
#  'back': 938,
#  'pack': 9098,
#  'blower': 1407,
#  'employe': 4247,
#  'ac': 48,
#  'unit': 13447,
#  'deer': 3408,
#  'valley': 13660,
#  'preserv': 9727,
#  'two': 13310,
#  'short': 11601,
#  'condens': 2740,
#  'motor': 8191,
#  'provid': 9893,
#  'estim': 4420,
#  'celest': 2032,
#  'email': 4211,
#  'cmr': 2481,
#  'approv': 630,
#  'escort': 4390,
#  'vendor': 13750,
#  'site': 11728,
#  'quot': 10079,
#  'thoma': 12873,
#  'wienand': 14214,
#  'request': 10566,
#  'wait': 13919,
#  'schedul': 11209,
#  'janen': 6531,
#  'werner': 14127,
#  'offic': 8722,
#  'veri': 13781,
#  'fab': 4572,
#  'flow': 4907,
#  'contact': 2841,
#  'name': 8383,
#  'phone': 9392,
#  'janenewernerasuedu': 6532,
#  'rais': 10114,
#  'thermostat': 12838,
#  'watch': 14002,
#  'system': 12537,
#  'react': 10182,
#  'chang': 2108,
#  'went': 14123,
#  'speak': 11970,
#  'occup': 8686,
#  'get': 5270,
#  'littl': 7340,
#  'warmer': 13965,
#  'classroom': 2356,
#  'toni': 13070,
#  'anthoni': 579,
#  'tucson': 13269,
#  'cav': 1984,
#  'recal': 10239,
#  'tec': 12646,
#  'increas': 6209,
#  'boiler': 1442,
#  'walk': 13924,
#  'confirm': 2788,
#  'temp': 12678,
#  'talk': 12578,
#  'brenda': 1556,
#  'happi': 5648,
#  'van': 13693,
#  'wa': 13906,
#  'leak': 7107,
#  'fuel': 5112,
#  'nation': 8418,
#  'automot': 883,
#  'pump': 9948,
#  'gasket': 5210,
#  'engin': 4282,
#  'mount': 8249,
#  'correctlyth': 2968,
#  'soonpul': 11912,
#  'abov': 33,
#  'west': 14136,
#  'desk': 3537,
#  'tank': 12598,
#  'less': 7197,
#  'hvac': 6064,
#  'south': 11935,
#  'filter': 4763,
#  'condit': 2748,
#  'necessari': 8450,
#  'north': 8592,
#  'exhaust': 4514,
#  'exf': 4508,
#  'randi': 10139,
#  'randel': 10138,
#  'greas': 5442,
#  'bear': 1112,
#  'belt': 1211,
#  'joseph': 6677,
#  'mccormick': 7799,
#  'guard': 5521,
#  'sump': 12388,
#  'oil': 8764,
#  'tighten': 12936,
#  'electr': 4163,
#  'lug': 7494,
#  'read': 10187,
#  'cac': 1773,
#  'took': 13075,
#  'termin': 12753,
#  'foyer': 5014,
#  'drink': 3929,
#  'fountain': 5005,
#  'store': 12260,
#  'printcreat': 9774,
#  'draw': 3909,
#  'pete': 9358,
#  'robert': 10810,
#  'locker': 7377,
#  'made': 7545,
#  'printout': 9776,
#  'access': 60,
#  'terminix': 12754,
#  'technician': 12652,
#  'rooftop': 10879,
#  'redo': 10299,
#  'program': 9837,
#  'yo': 14495,
#  'verifi': 13783,
#  'cfm': 2075,
#  'salli': 11106,
#  'reast': 10223,
#  'satisfi': 11168,
#  'ater': 835,
#  'type': 13322,
#  'sign': 11672,
#  'recommend': 10276,
#  'order': 8939,
#  'kitchen': 6877,
#  'would': 14382,
#  'adhes': 171,
#  'like': 7268,
#  'wall': 13929,
#  'want': 13955,
#  'instal': 6325,
#  'confer': 2781,
#  'kathi': 6765,
#  'novak': 8618,
#  'game': 5189,
#  'plan': 9481,
#  'close': 2442,
#  'receiv': 10247,
#  'continu': 2854,
#  'ucb': 13331,
#  'courtyard': 3019,
#  'behind': 1194,
#  'art': 737,
#  'studio': 12329,
#  'auto': 874,
#  'manual': 7639,
#  'professor': 9829,
#  'sand': 11128,
#  'found': 5000,
#  'actuat': 126,
#  'movement': 8258,
#  'open': 8860,
#  'return': 10687,
#  'approxim': 632,
#  'ray': 10167,
#  'buss': 1742,
#  'ne': 8436,
#  'quadrant': 10042,
#  'sever': 11453,
#  'faculti': 4594,
#  'ask': 772,
#  'creat': 3084,
#  'webtma': 14077,
#  'one': 8820,
#  'half': 5584,
#  'hour': 5987,
#  'mark': 7686,
#  'complet': 2645,
#  'onto': 8849,
#  'comput': 2714,
#  'later': 7062,
#  'thing': 12864,
#  'undo': 13421,
#  'stand': 12127,
#  'alon': 447,
#  'card': 1898,
#  'reader': 10190,
#  'routin': 10976,
#  'may': 7771,
#  'readr': 10197,
#  'holguin': 5925,
#  'abl': 26,
#  'entir': 4308,
#  'barrett': 1035,
#  'suit': 12374,
#  'sunday': 12392,
#  'april': 640,
#  'ensur': 4300,
#  'ah': 289,
#  'startup': 12148,
#  'monitor': 8138,
#  'directori': 3656,
#  'runner': 11039,
#  'requir': 10595,
#  'must': 8344,
#  'thursday': 12913,
#  'darrel': 3296,
#  'count': 3000,
#  'put': 10012,
#  'fix': 4830,
#  'good': 5363,
#  'fail': 4603,
#  'cost': 2982,
#  'tmp': 13012,
#  'tw': 13300,
#  'bill': 1320,
#  'part': 9193,
#  'travel': 13172,
#  'tofrom': 13039,
#  'rock': 10828,
#  'center': 2045,
#  'defect': 3411,
#  'top': 13080,
#  'handler': 5618,
#  'fuse': 5142,
#  'proper': 9875,
#  'three': 12894,
#  'pmd': 9555,
#  'addit': 153,
#  'problem': 9798,
#  'wo': 14289,
#  'veh': 13739,
#  'daniel': 3270,
#  'tanner': 12601,
#  'look': 7410,
#  'fluid': 4926,
#  'level': 7204,
#  'add': 148,
#  'sea': 11308,
#  'foam': 4943,
#  'ga': 5160,
#  'tune': 13281,
#  'let': 7201,
#  'shop': 11582,
#  'manag': 7616,
#  'know': 6921,
#  'flash': 4853,
#  'come': 2582,
#  'flack': 4840,
#  'sweep': 12485,
#  'screen': 11274,
#  'suppli': 12419,
#  'nois': 8560,
#  'em': 4208,
#  'heat': 5754,
#  'caus': 1982,
#  'unnecessarili': 13522,
#  'third': 12868,
#  'consist': 2821,
#  'end': 4269,
#  'section': 11339,
#  'modifi': 8098,
#  'longer': 7401,
#  'peopl': 9313,
#  'much': 8290,
#  'clog': 2435,
#  'jack': 6492,
#  'joe': 6647,
#  'mitsubishi': 8064,
#  'depart': 3497,
#  'today': 13030,
#  'vent': 13754,
#  'power': 9676,
#  'box': 1504,
#  'mode': 8085,
#  'excess': 4498,
#  'airflow': 337,
#  'greatli': 5455,
#  'reduc': 10302,
#  'space': 11947,
#  'result': 10669,
#  'fell': 4719,
#  'plexigla': 9523,
#  'didnt': 3607,
#  'break': 1543,
#  'refit': 10324,
#  'tap': 12606,
#  'everyth': 4468,
#  'clock': 2429,
#  'batteri': 1083,
#  'biannual': 1302,
#  'tmclk': 13010,
#  'aa': 0,
#  'cent': 2044,
#  'gailey': 5173,
#  'tire': 12991,
#  'pressur': 9735,
#  'four': 5008,
#  'central': 2051,
#  'plant': 9484,
#  'basement': 1051,
#  'weld': 14108,
#  'personnel': 9350,
#  'easili': 4058,
#  'align': 411,
#  'rush': 11057,
#  'job': 6638,
#  'panel': 9152,
#  'black': 1352,
#  'xs': 14451,
#  'pop': 9628,
#  'buzz': 1754,
#  'sound': 11931,
#  'ani': 549,
#  'question': 10062,
#  'adrian': 213,
#  'deloera': 3470,
#  'maint': 7580,
#  'mech': 7837,
#  'danielek': 3273,
#  'dan': 3258,
#  'fl': 4838,
#  'handicap': 5613,
#  'librari': 7231,
#  'sam': 11112,
#  'unwir': 13563,
#  'help': 5808,
#  'wire': 14255,
#  'establish': 4412,
#  'case': 1946,
#  'grind': 5483,
#  'present': 9725,
#  'connect': 2798,
#  'hous': 5988,
#  'len': 7181,
#  'street': 12288,
#  'pole': 9592,
#  'man': 7613,
#  'chick': 2217,
#  'fil': 4752,
#  'elect': 4162,
#  'survey': 12444,
#  'confin': 2787,
#  'entri': 4314,
#  'train': 13133,
#  'meet': 7856,
#  'take': 12574,
#  'place': 9473,
#  'cooler': 2901,
#  'jim': 6618,
#  'jame': 6520,
#  'spratta': 12033,
#  'lower': 7454,
#  'solar': 11871,
#  'troubleshoot': 13228,
#  'deltasol': 3473,
#  'mx': 8364,
#  'solenoid': 11874,
#  'coil': 2516,
#  'dump': 3993,
#  'line': 7284,
#  'buy': 1752,
#  'narrow': 8404,
#  'sdfc': 11295,
#  'use': 13620,
#  'puller': 9939,
#  'old': 8791,
#  'stem': 12200,
#  'resist': 10634,
#  'start': 12142,
#  'bleed': 1382,
#  'blood': 1404,
#  'drive': 3935,
#  'heater': 5763,
#  'annual': 565,
#  'wh': 14160,
#  'anod': 568,
#  'hala': 5583,
#  'usual': 13628,
#  'coupl': 3007,
#  'loud': 7436,
#  'investig': 6404,
#  'ceil': 2016,
#  'grid': 5472,
#  'insul': 6344,
#  'posit': 9649,
#  'grate': 5434,
#  'loos': 7415,
#  'wheel': 14167,
#  'secur': 11340,
#  'elimin': 4188,
#  'sourc': 11933,
#  'bike': 1317,
#  'co': 2489,
#  'op': 8857,
#  'low': 7452,
#  'doesnt': 3787,
#  'well': 14112,
#  'address': 157,
#  'earlier': 4049,
#  'improv': 6176,
#  'weak': 14060,
#  'fixtur': 4836,
#  'apart': 603,
#  'compress': 2694,
#  'restrict': 10663,
#  'past': 9219,
#  'session': 11430,
#  'tuesday': 13273,
#  'night': 8524,
#  'instructor': 6340,
#  'caryin': 1944,
#  'pool': 9619,
#  'kevin': 6822,
#  'brenden': 1559,
#  'ad': 140,
#  'bag': 975,
#  'sod': 11852,
#  'bicarb': 1307,
#  'backwash': 959,
#  'sandfilt': 11134,
#  'edward': 4108,
#  'hendrickson': 5818,
#  'chemic': 2193,
#  'perform': 9331,
#  'chem': 2192,
#  'normal': 8586,
#  'sodium': 11855,
#  'bi': 1300,
#  'carb': 1894,
#  'acid': 98,
#  'drum': 3951,
#  'clorin': 2441,
#  'tablet': 12556,
#  'equip': 4352,
#  'overnight': 9062,
#  'ran': 10134,
#  'cleanmaintain': 2383,
#  'glacier': 5310,
#  'bio': 1329,
#  'carbant': 1895,
#  'sampl': 11121,
#  'barrel': 1033,
#  'wash': 13985,
#  'lb': 7090,
#  'twice': 13307,
#  'staffnot': 12103,
#  'accutab': 83,
#  'feeder': 4709,
#  'arrang': 726,
#  'concentr': 2722,
#  'pick': 9410,
#  'ugli': 13345,
#  'life': 7241,
#  'retriev': 10683,
#  'grommet': 5497,
#  'bottom': 1492,
#  'flush': 4932,
#  'pumphous': 9957,
#  'tab': 12551,
#  'bicarbon': 1309,
#  'chlorin': 2254,
#  'granul': 5427,
#  'road': 10796,
#  'trip': 13214,
#  'neg': 8464,
#  'edg': 4100,
#  'support': 12424,
#  'got': 5393,
#  'checl': 2186,
#  'outpool': 9018,
#  'ph': 9378,
#  'scope': 11248,
#  'price': 9762,
#  'avail': 893,
#  'product': 9824,
#  'deck': 3384,
#  'northeast': 8594,
#  'corner': 2956,
#  'bicarban': 1308,
#  'empti': 4249,
#  'hr': 6007,
#  'mail': 7567,
#  'enter': 4302,
#  'save': 11178,
#  'safeti': 11086,
#  'glass': 5316,
#  'learn': 7146,
#  'mix': 8066,
#  'probe': 9792,
#  'compani': 2621,
#  'batch': 1065,
#  'palintest': 9133,
#  'could': 2994,
#  'alreadi': 456,
#  'action': 119,
#  'palin': 9132,
#  'shift': 11558,
#  'review': 10701,
#  'procur': 9822,
#  'warehous': 13962,
#  'transport': 13155,
#  'mechan': 7838,
#  'futur': 5155,
#  'dispos': 3736,
#  'compactor': 2618,
#  'move': 8256,
#  'build': 1676,
#  'intak': 6351,
#  'cobweb': 2499,
#  'swept': 12492,
#  'debri': 3371,
#  'calibr': 1815,
#  'ohm': 8762,
#  'ab': 13,
#  'correctli': 2964,
#  'centrifug': 2052,
#  'cwp': 3207,
#  'zerk': 14531,
#  'fit': 4826,
#  'assum': 813,
#  'seal': 11309,
#  'ten': 12735,
#  'minut': 8033,
#  'stop': 12251,
#  'wipe': 14253,
#  'pip': 9443,
#  'basepl': 1052,
#  'plug': 9532,
#  'restroom': 10665,
#  'intermitt': 6374,
#  'ar': 649,
#  'har': 5649,
#  'disconnect': 3683,
#  'difficulti': 3619,
#  'larg': 7044,
#  'scoreboard': 11250,
#  'field': 4744,
#  'befor': 1183,
#  'doubl': 3853,
#  'temper': 12685,
#  'clcc': 2365,
#  'extrem': 4564,
#  'yesterday': 14481,
#  'observ': 8671,
#  'drop': 3945,
#  'custom': 3188,
#  'comfort': 2586,
#  'garbag': 5197,
#  'salvajor': 11110,
#  'commerci': 2602,
#  'gm': 5336,
#  'labor': 6993,
#  'readi': 10191,
#  'rj': 10787,
#  'greg': 5463,
#  'mauro': 7764,
#  'per': 9316,
#  'jowel': 6687,
#  'voltag': 13883,
#  'note': 8603,
#  'wind': 14237,
#  'wors': 14374,
#  'fine': 4797,
#  'often': 8757,
#  'rough': 10966,
#  'vibrat': 13816,
#  'afternoon': 254,
#  'possibl': 9657,
#  'erika': 4373,
#  'recalibr': 10241,
#  'erica': 4367,
#  'ansswer': 574,
#  'nessag': 8476,
#  'show': 11617,
#  'uncertain': 13380,
#  'reason': 10216,
#  'random': 10140,
#  'occurr': 8690,
#  'aux': 888,
#  'wear': 14064,
#  'cycl': 3210,
#  'starter': 12144,
#  'overload': 9060,
#  'chill': 2227,
#  'valv': 13664,
#  'evap': 4446,
#  'vacuum': 13647,
#  'insid': 6292,
#  'trayreconnect': 13176,
#  'fill': 4757,
#  'tray': 13174,
#  'refer': 10316,
#  'rodney': 10841,
#  'moor': 8154,
#  'bid': 1311,
#  'tin': 12983,
#  'shed': 11527,
#  'list': 7330,
#  'due': 3985,
#  'rob': 10805,
#  'tile': 12940,
#  'stain': 12111,
#  'ahu': 304,
#  'optim': 8928,
#  'dew': 3569,
#  'humid': 6038,
#  'current': 3174,
#  'produc': 9823,
#  'reveal': 10694,
#  'indic': 6223,
#  'prolong': 9861,
#  'correl': 2969,
#  'typic': 13323,
#  'prone': 9867,
#  'pipe': 9444,
#  'conduit': 2776,
#  'protrud': 9891,
#  'data': 3305,
#  'info': 6243,
#  'gather': 5224,
#  'inventori': 6399,
#  'split': 12016,
#  'actual': 125,
#  'second': 11335,
#  'eq': 4341,
#  'discrep': 3698,
#  'tma': 13005,
#  'spent': 11992,
#  'organ': 8950,
#  'transcrib': 13140,
#  'bldg': 1375,
#  'domest': 3799,
#  'exchang': 4499,
#  'eqip': 4343,
#  'directli': 3654,
#  'boss': 1487,
#  'sheet': 11530,
#  'pictur': 9415,
#  'lost': 7432,
#  'abil': 25,
#  'catherin': 1975,
#  'front': 5085,
#  'hotter': 5982,
#  'month': 8147,
#  'ago': 279,
#  'weather': 14067,
#  'outsid': 9023,
#  'ideal': 6119,
#  'id': 6116,
#  'thermomet': 12832,
#  'siemen': 11665,
#  'page': 9110,
#  'jump': 6717,
#  'cool': 2895,
#  'concret': 2733,
#  'mixer': 8067,
#  'portmixr': 9644,
#  'spark': 11959,
#  'lube': 7482,
#  'medco': 7845,
#  'key': 6825,
#  'machin': 7532,
#  'graffiti': 5416,
#  'island': 6443,
#  'avet': 900,
#  'bird': 1342,
#  'gate': 5220,
#  'yard': 14462,
#  'paint': 9117,
#  'vfd': 13801,
#  'shut': 11642,
#  'isol': 6449,
#  'bring': 1594,
#  'determin': 3558,
#  'interfer': 6368,
#  'friction': 5060,
#  'dure': 4012,
#  'rotat': 10951,
#  'hydraul': 6088,
#  'press': 9731,
#  'push': 10010,
#  'impel': 6163,
#  'shaft': 11474,
#  'cut': 3194,
#  'assembl': 781,
#  'variou': 13709,
#  'burn': 1730,
#  'smell': 11804,
#  'faint': 4611,
#  'caller': 1826,
#  'lamp': 7019,
#  'tip': 12990,
#  'shredder': 11631,
#  'copi': 2935,
#  'soften': 11862,
#  'heatcool': 5760,
#  'remain': 10419,
#  'march': 7662,
#  'extend': 4551,
#  'barret': 1034,
#  'colleg': 2563,
#  'near': 8438,
#  'around': 722,
#  'balanc': 988,
#  'project': 9858,
#  'pf': 9372,
#  'graphic': 5430,
#  'aid': 318,
#  'databas': 3306,
#  'hard': 5651,
#  'origin': 8959,
#  'valu': 13662,
#  'map': 7653,
#  'cadav': 1777,
#  'correct': 2962,
#  'error': 4383,
#  'vav': 13716,
#  'templat': 12710,
#  'visibl': 13852,
#  'document': 3781,
#  'crew': 3094,
#  'fire': 4806,
#  'team': 12642,
#  'technic': 12650,
#  'sir': 11720,
#  'backup': 956,
#  'minimum': 8025,
#  'maximum': 7769,
#  'write': 14403,
#  'ppcl': 9689,
#  'match': 7734,
#  'trc': 13185,
#  'coeffient': 2511,
#  'cpgen': 3043,
#  'away': 914,
#  'touch': 13100,
#  'curb': 3164,
#  'cb': 1992,
#  'vac': 13641,
#  'mop': 8156,
#  'scour': 11264,
#  'pad': 9104,
#  'buffer': 1668,
#  'eastern': 4060,
#  'phase': 9381,
#  'base': 1045,
#  'ch': 2080,
#  'amp': 503,
#  'yellow': 14476,
#  'sort': 11924,
#  'spare': 11958,
#  'storag': 12256,
#  'mess': 7911,
#  'sf': 11461,
#  'began': 1185,
#  'tube': 13264,
#  'punch': 9994,
#  'coat': 2495,
#  'chip': 2235,
#  'dirt': 3658,
#  'drill': 3928,
#  'trash': 13160,
#  'scrap': 11267,
#  'metal': 7919,
#  'recycl': 10293,
#  'bin': 1325,
#  'chiller': 2228,
#  'bay': 1095,
#  'soap': 11846,
#  'fairli': 4616,
#  'clear': 2390,
#  'loop': 7413,
#  'tunnel': 13282,
#  'entranc': 4311,
#  'eastward': 4062,
#  'layer': 7086,
#  'grime': 5482,
#  'cleaneddust': 2373,
#  'pvc': 10018,
#  'pipinglin': 9453,
#  'straighten': 12273,
#  'treatment': 13190,
#  'reorgan': 10466,
#  'shelv': 11545,
#  'right': 10755,
#  'materi': 7736,
#  'ore': 8947,
#  'motorsand': 8240,
#  'tabl': 12555,
#  'big': 1314,
#  'stuff': 12333,
#  'way': 14037,
#  'finish': 4802,
#  'stage': 12106,
#  'til': 12939,
#  'bead': 1108,
#  'blaster': 1370,
#  'pic': 9407,
#  'loosen': 7417,
#  'repack': 10469,
#  'tower': 13106,
#  'blast': 1369,
#  'prep': 9720,
#  'begin': 1187,
#  'rust': 11060,
#  'tool': 13076,
#  'haul': 5697,
#  'dumpster': 3995,
#  'pillar': 9425,
#  'last': 7056,
#  'whenev': 14178,
#  'tell': 12674,
#  'next': 8500,
#  'wed': 14078,
#  'ahead': 295,
#  'wringer': 14401,
#  'await': 908,
#  'week': 14089,
#  'surfac': 12433,
#  'bsmt': 1649,
#  'frame': 5019,
#  'worthless': 14379,
#  'golf': 5355,
#  'cart': 1939,
#  'charger': 2138,
#  'dirti': 3660,
#  'kiva': 6891,
#  'mezzanin': 7934,
#  'uv': 13638,
#  'filtrat': 4788,
#  'flat': 4856,
#  'plate': 9493,
#  'studentcent': 12326,
#  'rec': 10238,
#  'lock': 7373,
#  'inoper': 6275,
#  'refinish': 10323,
#  'tag': 12565,
#  'ct': 3141,
#  'ice': 6105,
#  'thick': 12859,
#  'clariti': 2352,
#  'accept': 59,
#  'cleanli': 2382,
#  'mold': 8114,
#  'growth': 5510,
#  'evapor': 4451,
#  ...}

# %%
# Train Word2Vec Model from all the tokenized documents after stemming
model = gensim.models.Word2Vec(stemmed_issues, min_count=1, size=100)
model.save('word2vec_model')

# %%
stemmed_issues[0]
# Out:
# ['portabl', 'gener', 'mainten', 'monthli', 'nan', 'nan']

# %%
#TODO: Need to remove stop words
len(model.wv.vocab)
# Out:
# 15026

# %%
np.shape(model.wv['mainten'])
# Out:
# (100,)

# %%
def generate_sentence_vector(tokens, model, vectorizer, tfidf_dense):
    vector = np.zeros(model.vector_size)
    for token in tokens:
        if token in model.wv.vocab and token in vectorizer.vocabulary_:
            vector = vector + model.wv[token] * tfidf_dense[0,vectorizer.vocabulary_[token]]
    return vector

# %%
issue_features = []
for i in range(0,len(stemmed_issues)):
    
    issue_features.append(generate_sentence_vector(stemmed_issues[i], model, vectorizer, tfidf_dense[i]))
np.shape(issue_features)
# Out:
# (43041, 100)

# %%
list(df)
# Out:
# ['Work.Order',
#  'WO.Type',
#  'Charge.Type',
#  'Reference.Number',
#  'Project',
#  'Action.Requested',
#  'Priority',
#  'Status',
#  'Requestor',
#  'Req.Phone',
#  'Department',
#  'Dept.Number',
#  'Account.Number.s.',
#  'Campus',
#  'Building',
#  'Floor',
#  'Area',
#  'Area.Function',
#  'Area.Type',
#  'Object.Type',
#  'WO.Object',
#  'Date.Requested',
#  'Date.Estimate.Began',
#  'Date.Estimate.Was.Completed',
#  'Days.to.Estimate.Completed',
#  'Date.WO.Issued',
#  'Days.to.Issue',
#  'Scheduled.Start.Date',
#  'Date.Funded',
#  'Funded.Amount',
#  'First.Charge',
#  'Days.to.Start',
#  'Scheduled.Completion.Date',
#  'Date.Finished',
#  'Days.to.Finish',
#  'Date.Completed',
#  'Days.to.Completion',
#  'Labor.Hours',
#  'FM.Labor',
#  'Flat.Bill',
#  'Warehouse.Parts',
#  'NonStock.Received.and.Invoiced',
#  'NonStock.Received.Not.Invoiced',
#  'NonStock.On.Order.Not.Received',
#  'Total',
#  'Assigned.Trades',
#  'General.Comments',
#  'Task.Comments',
#  'Topics',
#  'filter',
#  'total',
#  'vent',
#  'Gauges',
#  'Thermometers',
#  'thermocouple',
#  'Thermostat',
#  'cage',
#  'pump',
#  'air_conditioner',
#  'Furnace',
#  'Refrigerant',
#  'coil',
#  'alarm',
#  'generator',
#  'condens',
#  'fan',
#  'motor',
#  'Evaporative_Cooler',
#  'light',
#  'control_panel',
#  'control_board',
#  'breaker',
#  'handler',
#  'pipe',
#  'capacitor',
#  'filter.1',
#  'magnets',
#  'fuse',
#  'leak',
#  'battery',
#  'freezer',
#  'bearing',
#  'heating_unit',
#  'cooling_unit',
#  'cooler',
#  'wire',
#  'switch',
#  'button',
#  'contactor',
#  'sink',
#  'actuator',
#  'detector',
#  'compress',
#  'chiller',
#  'humidifier',
#  'duct',
#  'broke',
#  'valve',
#  'lock',
#  'chemical',
#  'TRC',
#  'TEC',
#  'Fridg',
#  'damper',
#  'CAV',
#  'VAV',
#  'component']

# %%
issue_vector_df = pd.DataFrame()
issue_vector_df['Work.Order'] = df['Work.Order']
issue_vector_df['Action.Requested'] = df['Action.Requested']
issue_vector_df['General.Comments'] = df['General.Comments']
issue_vector_df['Task.Comments'] = df['Task.Comments']
issue_vector_df['Building'] = df['Building']
issue_vector_df['Campus'] = df['Campus']
issue_vector_df['Total'] = df['Total']
issue_vector_df['Text.Vector'] = issue_features

# %%
issue_vector_df.head()
# Out:
#     Work.Order                                   Action.Requested  \
# 1  WEST-111222             Portable Generator Maintenance-Monthly
# 2  WEST-111219                   Roof Drain Quarterly Maintenance
# 3  WEST-111213  Marcos with SACS called to report the ballroom...
# 4  WEST-111208  The sink in our lobby area is not working. The...
# 5  WEST-111206  Please adjust the temperature in the lab to ap...
#
#   General.Comments                                      Task.Comments  \
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN  2017-05-19 - 18290 - Donald Miller-Checked la ...
# 4              NaN  2017-05-18 - 23070 - Tim Jowers-pulled it down...
# 5              NaN  2017-05-18 - 18300 - Chad T Ball-Adjusted set ...
#
#                                  Building       Campus  Total  \
# 1          906 - CENTRAL SERVICES COMPLEX  West Campus   0.00
# 2           903 - UNIVERSITY CENTER - 903  West Campus   0.00
# 3           903 - UNIVERSITY CENTER - 903  West Campus  46.72
# 4           903 - UNIVERSITY CENTER - 903  West Campus  93.44
# 5  905 - CLASSROOM/LAB/COMPUTER CLASSROOM  West Campus   0.00
#
#                                          Text.Vector
# 1  [-0.223442912102, 0.775393560529, 1.0544666517...
# 2  [-1.36261639744, 2.07899846137, -0.37214660644...
# 3  [0.816895168449, -0.226713138167, 0.1999728232...
# 4  [-1.29352224525, 0.387565576471, -2.3586586981...
# 5  [-0.398334584788, -3.6127059297, 1.25289469102...

# %%
issue_vector_df.to_pickle('issue_text_vector.pkl')
