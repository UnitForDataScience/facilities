# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd       
train = pd.read_csv("E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/train.csv", header=0, encoding="cp1252", low_memory=False)

# %%
#Dimensions of the dataframe
train.shape
# Out:
# (20676, 7)

# %%
#Displaying Column labels
train.columns.values
# Out:
# array(['Unnamed: 0', 'WorkOrder', 'WOType', 'ActionRequested', 'Priority',
#        'WO', 'WOPriority'], dtype=object)

# %% [markdown]
# ### Data Cleaning and Text Preprocessing

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup             
import re
import nltk
# Download text data sets, including stop words
from nltk.corpus import stopwords

# %%
#Function to reuse the code
def maintenance( tma ):
    # Function to convert a raw action request to a string of words
    # The input is a single string, and 
    # the output is a single string (a processed action request)
    #
    # 1. Remove HTML
    text = BeautifulSoup(tma,"html.parser").get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
# Get the number of requests based on the dataframe column size
num_requests = train["ActionRequested"].size

# Initialize an empty list to hold the clean requests
clean_train_requests = []

# Loop over each request; create an index i that goes from 0 to the length
# of the maintenance request list 
for i in range( 0, num_requests ):
    # Call our function for each one, and add the result to the list of
    # clean requests
    clean_train_requests.append(maintenance( train["ActionRequested"][i] ) )

# %% [markdown]
# ### Creating Features from a Bag of Words

# %%
print( "Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_requests)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
#tdf = pd.DataFrame(train_data_features)
#tdf.to_csv("E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/wordvectors.csv")

# %%
print(train_data_features.shape)
# Out:
# (20676, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['aa', 'aaron', 'ab', 'abandoned', 'abb', 'abi', 'able', 'ablnj', 'abroad', 'ac', 'academic', 'acba', 'acc', 'accent', 'acceptable', 'accepted', 'access', 'accessible', 'accident', 'accidentally', 'accommodate', 'according', 'accordingly', 'account', 'accumulated', 'accumulating', 'acic', 'acm', 'acmm', 'acourtia', 'across', 'action', 'activate', 'activated', 'active', 'activities', 'activity', 'actual', 'actually', 'actuator', 'acuna', 'ad', 'ada', 'adam', 'adapter', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'adelphi', 'adeq', 'adhere', 'adhered', 'adjacent', 'adjoining', 'adjust', 'adjusted', 'adjusting', 'adjustment', 'adjustments', 'adl', 'admin', 'administration', 'administrative', 'admissions', 'adnim', 'adot', 'adrienne', 'advance', 'advice', 'advise', 'advised', 'ae', 'aef', 'aek', 'aemarqu', 'aenhg', 'aerator', 'aev', 'af', 'afc', 'affairs', 'affect', 'affected', 'affecting', 'affiliate', 'afraid', 'afternoon', 'ag', 'agave', 'agbc', 'agency', 'agent', 'ago', 'aguirre', 'ah', 'ahead', 'ahlers', 'ahlf', 'ahmed', 'ahs', 'ahu', 'ahuvfd', 'ai', 'aid', 'aihfl', 'air', 'airflow', 'aisle', 'aj', 'ajl', 'ak', 'akl', 'al', 'alameda', 'alan', 'alana', 'alarm', 'alarms', 'alcove', 'alex', 'alexander', 'alicia', 'align', 'aligned', 'alignment', 'alkaabi', 'allan', 'allen', 'alley', 'allow', 'allowing', 'alltown', 'almost', 'alone', 'along', 'alot', 'alpha', 'already', 'also', 'alternate', 'although', 'altitude', 'alumni', 'always', 'amanda', 'ambassador', 'amber', 'american', 'amfkl', 'amount', 'amounts', 'amp', 'amy', 'ana', 'anabel', 'anchor', 'anderson', 'andrew', 'angel', 'angle', 'animal', 'anisha', 'ann', 'anna', 'anne', 'annex', 'annoying', 'annual', 'another', 'answer', 'ant', 'anthony', 'antonio', 'ants', 'anymore', 'anyone', 'anything', 'anytime', 'anyway', 'anywhere', 'ao', 'aoce', 'apache', 'apart', 'apartment', 'apartments', 'apegg', 'apma', 'apologies', 'apologize', 'apparently', 'appear', 'appeared', 'appears', 'appliances', 'applied', 'apply', 'appreciate', 'appreciated', 'appropriate', 'appropriately', 'approval', 'approved', 'approx', 'approximately', 'april', 'apt', 'aquat', 'aquatic', 'ar', 'aramark', 'arava', 'area', 'areas', 'arena', 'ariel', 'arizona', 'arm', 'armstrong', 'around', 'arrange', 'arrieta', 'arrival', 'arrive', 'arrived', 'arriving', 'arroyo', 'art', 'artistic', 'arts', 'asap', 'asbestos', 'ashley', 'ashwin', 'aside', 'ask', 'asked', 'asking', 'asleep', 'assemble', 'assembly', 'assess', 'assessed', 'assign', 'assigned', 'assist', 'assistance', 'assistant', 'assistants', 'associate', 'associated', 'assume', 'asu', 'asucentury', 'asuhc', 'asuhd', 'asupd', 'asurite', 'athena', 'athletic', 'atrium', 'attach', 'attached', 'attachment', 'attempted', 'attempting', 'attempts', 'attend', 'attendance', 'attended', 'attention', 'attn', 'audit', 'auditorium', 'aug', 'auger', 'august', 'austin', 'authorizer', 'auto', 'automatic', 'automatically', 'autumn', 'av', 'available', 'ave', 'avenue', 'avoid', 'aw', 'aware', 'away', 'awesome', 'awful', 'awhile', 'awning', 'az', 'ba', 'baa', 'baby', 'bac', 'back', 'backed', 'backflow', 'backing', 'backs', 'backup', 'bad', 'badge', 'badly', 'baef', 'bag', 'bagged', 'bags', 'bai', 'bailey', 'bait', 'baker', 'balance', 'balcony', 'ball', 'ballast', 'ballroom', 'band', 'banging', 'bank', 'banner', 'banners', 'bar', 'barb', 'barbara', 'barely', 'barnby', 'barrett', 'bars', 'bas', 'base', 'baseball', 'baseboard', 'baseboards', 'based', 'basement', 'basically', 'basin', 'basis', 'basket', 'basketball', 'bat', 'bateman', 'bath', 'bathroom', 'bathrooms', 'bathtub', 'batteries', 'battery', 'bay', 'bb', 'bbq', 'bc', 'bceng', 'bcgn', 'bcls', 'bd', 'bda', 'bdb', 'bde', 'bdedf', 'bdhoi', 'bdk', 'beam', 'beams', 'bearing', 'bearings', 'beck', 'becky', 'become', 'becoming', 'bed', 'bedroom', 'bedrooms', 'beds', 'bedspace', 'bee', 'beep', 'beeping', 'beeps', 'bees', 'began', 'begay', 'begin', 'beginning', 'behalf', 'behind', 'believe', ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# %%
# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 20 aa
# 8 aaron
# 21 ab
# 9 abandoned
# 15 abb
# 5 abi
# 97 able
# 6 ablnj
# 5 abroad
# 365 ac
# 26 academic
# 5 acba
# 118 acc
# 11 accent
# 6 acceptable
# 7 accepted
# 218 access
# 7 accessible
# 6 accident
# 8 accidentally
# 15 accommodate
# 10 according
# 36 accordingly
# 71 account
# 4 accumulated
# 4 accumulating
# 7 acic
# 38 acm
# 10 acmm
# 7 acourtia
# 41 across
# 19 action
# 7 activate
# 7 activated
# 18 active
# 3 activities
# 110 activity
# 14 actual
# 22 actually
# 7 actuator
# 4 acuna
# 21 ad
# 97 ada
# 6 adam
# 3 adapter
# 86 add
# 35 added
# 8 adding
# 8 addition
# 44 additional
# 15 additionally
# 317 address
# 29 addressed
# 105 adelphi
# 13 adeq
# 4 adhere
# 7 adhered
# 19 adjacent
# 7 adjoining
# 162 adjust
# 53 adjusted
# 10 adjusting
# 26 adjustment
# 21 adjustments
# 4 adl
# 13 admin
# 50 administration
# 12 administrative
# 3 admissions
# 5 adnim
# 8 adot
# 8 adrienne
# 38 advance
# 5 advice
# 17 advise
# 16 advised
# 25 ae
# 7 aef
# 4 aek
# 18 aemarqu
# 9 aenhg
# 10 aerator
# 5 aev
# 8 af
# 4 afc
# 5 affairs
# 4 affect
# 5 affected
# 5 affecting
# 22 affiliate
# 5 afraid
# 39 afternoon
# 8 ag
# 9 agave
# 26 agbc
# 331 agency
# 309 agent
# 70 ago
# 4 aguirre
# 32 ah
# 5 ahead
# 21 ahlers
# 4 ahlf
# 42 ahmed
# 8 ahs
# 42 ahu
# 8 ahuvfd
# 35 ai
# 4 aid
# 4 aihfl
# 1432 air
# 11 airflow
# 7 aisle
# 21 aj
# 7 ajl
# 14 ak
# 5 akl
# 37 al
# 15 alameda
# 4 alan
# 4 alana
# 297 alarm
# 16 alarms
# 6 alcove
# 6 alex
# 8 alexander
# 23 alicia
# 4 align
# 5 aligned
# 8 alignment
# 5 alkaabi
# 8 allan
# 10 allen
# 4 alley
# 31 allow
# 13 allowing
# 68 alltown
# 32 almost
# 8 alone
# 44 along
# 5 alot
# 5 alpha
# 91 already
# 411 also
# 8 alternate
# 10 although
# 4 altitude
# 4 alumni
# 34 always
# 10 amanda
# 7 ambassador
# 6 amber
# 4 american
# 6 amfkl
# 57 amount
# 13 amounts
# 13 amp
# 13 amy
# 5 ana
# 4 anabel
# 5 anchor
# 15 anderson
# 12 andrew
# 11 angel
# 13 angle
# 9 animal
# 3 anisha
# 9 ann
# 6 anna
# 16 anne
# 8 annex
# 7 annoying
# 675 annual
# 51 another
# 15 answer
# 27 ant
# 22 anthony
# 4 antonio
# 86 ants
# 19 anymore
# 13 anyone
# 37 anything
# 4 anytime
# 5 anyway
# 3 anywhere
# 24 ao
# 5 aoce
# 8 apache
# 28 apart
# 139 apartment
# 8 apartments
# 5 apegg
# 8 apma
# 3 apologies
# 9 apologize
# 11 apparently
# 18 appear
# 4 appeared
# 98 appears
# 4 appliances
# 5 applied
# 6 apply
# 47 appreciate
# 46 appreciated
# 15 appropriate
# 8 appropriately
# 11 approval
# 39 approved
# 16 approx
# 12 approximately
# 32 april
# 5 apt
# 4 aquat
# 7 aquatic
# 4 ar
# 30 aramark
# 7 arava
# 655 area
# 101 areas
# 15 arena
# 4 ariel
# 29 arizona
# 14 arm
# 21 armstrong
# 158 around
# 8 arrange
# 9 arrieta
# 16 arrival
# 5 arrive
# 12 arrived
# 11 arriving
# 6 arroyo
# 95 art
# 5 artistic
# 17 arts
# 346 asap
# 107 asbestos
# 6 ashley
# 3 ashwin
# 4 aside
# 21 ask
# 27 asked
# 18 asking
# 7 asleep
# 5 assemble
# 16 assembly
# 10 assess
# 3 assessed
# 66 assign
# 8 assigned
# 89 assist
# 98 assistance
# 16 assistant
# 4 assistants
# 8 associate
# 22 associated
# 9 assume
# 1058 asu
# 6 asucentury
# 260 asuhc
# 201 asuhd
# 13 asupd
# 18 asurite
# 3 athena
# 3 athletic
# 10 atrium
# 19 attach
# 229 attached
# 247 attachment
# 14 attempted
# 6 attempting
# 7 attempts
# 15 attend
# 25 attendance
# 3 attended
# 68 attention
# 4 attn
# 5 audit
# 19 auditorium
# 7 aug
# 4 auger
# 35 august
# 8 austin
# 505 authorizer
# 109 auto
# 34 automatic
# 17 automatically
# 6 autumn
# 5 av
# 37 available
# 22 ave
# 9 avenue
# 10 avoid
# 6 aw
# 19 aware
# 58 away
# 9 awesome
# 4 awful
# 9 awhile
# 4 awning
# 16 az
# 129 ba
# 4 baa
# 7 baby
# 69 bac
# 439 back
# 58 backed
# 104 backflow
# 30 backing
# 4 backs
# 5 backup
# 104 bad
# 4 badge
# 30 badly
# 4 baef
# 12 bag
# 15 bagged
# 13 bags
# 4 bai
# 3 bailey
# 5 bait
# 4 baker
# 13 balance
# 38 balcony
# 16 ball
# 27 ballast
# 6 ballroom
# 5 band
# 5 banging
# 6 bank
# 12 banner
# 7 banners
# 36 bar
# 3 barb
# 4 barbara
# 16 barely
# 6 barnby
# 51 barrett
# 10 bars
# 10 bas
# 50 base
# 4 baseball
# 8 baseboard
# 7 baseboards
# 4 based
# 77 basement
# 4 basically
# 7 basin
# 6 basis
# 8 basket
# 9 basketball
# 7 bat
# 5 bateman
# 31 bath
# 794 bathroom
# 25 bathrooms
# 40 bathtub
# 45 batteries
# 84 battery
# 6 bay
# 49 bb
# 5 bbq
# 27 bc
# 8 bceng
# 5 bcgn
# 7 bcls
# 21 bd
# 33 bda
# 19 bdb
# 3 bde
# 108 bdedf
# 3 bdhoi
# 11 bdk
# 6 beam
# 3 beams
# 10 bearing
# 12 bearings
# 13 beck
# 4 becky
# 18 become
# 7 becoming
# 256 bed
# 201 bedroom
# 11 bedrooms
# 16 beds
# 38 bedspace
# 11 bee
# 4 beep
# 51 beeping
# 5 beeps
# 24 bees
# 4 began
# 5 begay
# 6 begin
# 23 beginning
# 10 behalf
# 88 behind
# 49 believe
# 7 believes
# 4 bell
# 5 bellamy
# 6 belongings
# 14 belt
# 10 belts
# 5 ben
# 14 bench
# 4 beneath
# 4 bennett
# 35 bent
# 27 bergen
# 8 bergevin
# 9 berndt
# 80 best
# 4 beth
# 11 better
# 28 bf
# 7 bfdch
# 24 bfk
# 4 bfo
# 14 bg
# 6 bgi
# 26 bh
# 5 bhfb
# 5 bhhah
# 6 bhj
# 44 bi
# 1628 biannual
# 8 bib
# 4 bicycle
# 5 bid
# 6 bies
# 36 big
# 7 bigger
# 30 bike
# 90 bill
# 185 billed
# 53 billing
# 48 bimonthly
# 50 bin
# 27 bins
# 42 bio
# 8 biodesign
# 22 bird
# 29 biren
# 31 bit
# 4 biweekly
# 6 bjh
# 8 bk
# 4 bkikh
# 32 bl
# 59 black
# 13 blades
# 6 blakely
# 5 blanco
# 4 blank
# 34 blanket
# 5 blasting
# 17 bld
# 435 bldg
# 107 bleo
# 11 blew
# 93 blhkh
# 21 blind
# 95 blinds
# 14 blinking
# 4 blloo
# 11 block
# 7 blockage
# 17 blocked
# 9 blocking
# 13 blow
# 13 blower
# 77 blowing
# 21 blown
# 10 blows
# 43 blue
# 26 bm
# 5 bmja
# 30 bn
# 7 bo
# 111 board
# 27 boards
# 17 bob
# 8 body
# 12 boiler
# 6 bol
# 14 bollard
# 4 bollards
# 24 bolt
# 8 bolts
# 6 bone
# 26 bonnie
# 12 booher
# 8 book
# 7 bookcase
# 6 bookcases
# 3 booking
# 6 books
# 7 bookshelf
# 4 bookshelves
# 18 bookstore
# 9 booster
# 5 borucki
# 15 boss
# 23 bottle
# 6 bottles
# 114 bottom
# 3 bought
# 16 bowl
# 874 box
# 51 boxes
# 5 boys
# 9 bracamonte
# 15 bracket
# 9 brackets
# 7 brad
# 8 bradley
# 10 brady
# 29 brake
# 5 brakes
# 3 branch
# 4 branches
# 3 brand
# 23 brandon
# 3 brass
# 49 break
# 67 breaker
# 17 breakers
# 9 breaking
# 4 breakroom
# 10 breezeway
# 4 brenda
# 6 brendan
# 27 brenna
# 4 brent
# 83 brian
# 5 brick
# 15 bricker
# 5 bricks
# 12 bridge
# 21 briggs
# 4 bright
# 11 brimhall
# 20 bring
# 4 bringing
# 4 brittany
# 74 broke
# 694 broken
# 3 brooms
# 14 brought
# 43 brown
# 23 bruce
# 3 brugman
# 5 bryan
# 22 bryant
# 797 bt
# 4 bubble
# 5 bubbles
# 7 bubbling
# 18 bucket
# 3 budge
# 3 budget
# 34 bug
# 80 bugs
# 15 build
# 1082 building
# 50 buildings
# 4 builds
# 8 built
# 166 bulb
# 155 bulbs
# 17 bulletin
# 5 bunch
# 3 bunna
# 4 bunnies
# 11 burger
# 6 burn
# 94 burned
# 13 burner
# 7 burners
# 15 burning
# 208 burnt
# 5 bus
# 5 bush
# 28 business
# 10 bustillos
# 6 busy
# 4 butcher
# 83 button
# 24 buttons
# 13 buzzing
# 169 ca
# 5 cab
# 132 cabinet
# 49 cabinets
# 59 cable
# 8 cables
# 4 cac
# 3 cady
# 7 caf
# 15 cafe
# 3 cafeteria
# 3 cage
# 3 caked
# 4 cal
# 4 caldera
# 7 calendar
# 334 call
# 3 callback
# 4 callbox
# 338 called
# 18 caller
# 7 calling
# 56 calls
# 14 cam
# 128 came
# 6 cameron
# 93 campus
# 8 cancel
# 22 cancelled
# 88 cannot
# 24 cans
# 7 cant
# 4 cantina
# 20 cap
# 5 capacitor
# 33 car
# 54 card
# 5 cardboard
# 8 cards
# 69 care
# 13 career
# 10 carey
# 9 carl
# 47 carli
# 6 carlos
# 8 carol
# 4 caroleen
# 51 carpenter
# 38 carpentry
# 238 carpet
# 8 carpeting
# 21 carpets
# 5 carport
# 15 carson
# 51 cart
# 8 cartridge
# 18 carts
# 8 casas
# 41 case
# 8 cases
# 18 casey
# 8 cass
# 6 cast
# 9 cat
# 7 catalina
# 7 catch
# 3 catches
# 9 catching
# 8 catering
# 36 catherine
# 7 catwalk
# 3 caught
# 6 caulk
# 29 cause
# 27 caused
# 7 causes
# 80 causing
# 7 caution
# 29 cavc
# 3 cazarez
# 20 cb
# 5 cbeni
# 19 cc
# 26 cd
# 37 cdn
# 19 cds
# 12 ce
# 5 cea
# 3 cealing
# 3 cease
# 6 cedar
# 571 ceiling
# 23 cell
# 4 cem
# 331 center
# 3 centered
# 41 centerpoint
# 79 central
# 3 centric
# 196 centrifugal
# 40 century
# 5 centurylink
# 3 ceramic
# 5 ceramics
# 3 ceremony
# 11 cereus
# 5 certain
# 4 certification
# 9 cesar
# 12 cesperti
# 32 cf
# 3 cfa
# 6 cfc
# 7 cfl
# 14 cg
# 3 cgb
# 4 cgf
# 3 cgl
# 3 cgp
# 3 cgr
# 5 cgs
# 4 ch
# 3 cha
# 7 chad
# 20 chain
# 71 chair
# 37 chairs
# 5 chalk
# 43 chamber
# 3 chambers
# 4 chan
# 10 chance
# 3 chandelier
# 332 change
# 79 changed
# 17 changes
# 14 changing
# 3 chaplin
# 7 chapman
# 9 chapter
# 847 charge
# 10 chargeable
# 6 chargeback
# 39 charged
# 60 charges
# 18 charging
# 10 charles
# 7 charlie
# 22 charlotte
# 6 chase
# 7 chavez
# 1287 check
# 106 checked
# 14 checking
# 34 checkout
# 4 checks
# 15 chelsea
# 7 chemical
# 10 chemicals
# 5 cheryl
# 38 chet
# 4 chevrolet
# 6 chg
# 3 chick
# 11 child
# 4 childers
# 18 children
# 5 chill
# 57 chilled
# 48 chiller
# 6 chillers
# 6 chilly
# 9 ching
# 33 chip
# 10 chipped
# 3 chipping
# 27 chips
# 6 chirping
# 10 chisler
# 3 chismar
# 4 chld
# 6 chlorine
# 59 cholla
# 14 chollahall
# 4 chou
# 50 chris
# 4 christian
# 18 christine
# 11 christopher
# 8 chuparosa
# 15 chw
# 5 cigarette
# 15 cindi
# 51 cindy
# 5 circle
# 29 circuit
# 11 circuits
# 5 circular
# 15 circulating
# 18 circulation
# 10 city
# 6 cj
# 8 ck
# 7 cl
# 51 claim
# 4 claire
# 5 clarification
# 6 clarifications
# 12 clark
# 48 class
# 15 classes
# 110 classroom
# 19 classrooms
# 26 clcc
# 499 clean
# 227 cleaned
# 7 cleaner
# 156 cleaning
# 21 cleanup
# 69 clear
# 11 clearance
# 52 cleared
# 4 clearing
# 5 clearly
# 29 climatec
# 6 clint
# 5 clj
# 57 clock
# 5 clocks
# 13 clog
# 477 clogged
# 9 clogging
# 5 clogs
# 165 close
# 158 closed
# 42 closer
# 4 closers
# 19 closes
# 53 closest
# 173 closet
# 77 closing
# 12 closure
# 20 clothes
# 13 club
# 4 clubhouse
# 38 cluster
# 5 clusters
# 13 clutches
# 46 cm
# 5 cmh
# 31 cmr
# 5 cn
# 8 cntr
# 7 cntrpnt
# 17 cntrpt
# 23 co
# 5 coa
# 5 coaches
# 4 coat
# 6 cobwebs
# 9 cockroach
# 23 cockroaches
# 768 code
# 15 codes
# 21 coffee
# 68 coil
# 47 coils
# 5 colby
# 275 cold
# 10 colder
# 4 coldest
# 4 collapsed
# 4 collections
# 43 college
# 21 color
# 4 colorado
# 4 colored
# 7 colors
# 4 column
# 197 com
# 8 combination
# 4 combs
# 359 come
# 34 comes
# 6 comfort
# 6 comfortable
# 284 coming
# 5 comm
# 6 command
# 4 commencement
# 4 comments
# 61 common
# 38 commons
# 8 communications
# 32 community
# 14 compactor
# 16 company
# 12 compartment
# 5 competition
# 11 complaining
# 23 complaint
# 17 complaints
# 75 complete
# 106 completed
# 68 completely
# 14 completion
# 37 complex
# 5 components
# 113 compressor
# 7 compressors
# 42 computer
# 10 computers
# 17 computing
# 10 con
# 94 concern
# 10 concerned
# 4 concerning
# 7 concerns
# 5 concession
# 47 concourse
# 26 concrete
# 57 condensate
# 16 condensation
# 8 condenser
# 36 condensing
# 35 condition
# 52 conditioner
# 156 conditioning
# 6 conditions
# 18 conduct
# 8 conducted
# 13 conduit
# 5 conf
# 77 conference
# 16 confirm
# 7 confirmed
# 4 conhi
# 27 connect
# 30 connected
# 18 connecting
# 39 connection
# 6 connections
# 5 connects
# 8 connie
# 5 connor
# 12 consistently
# 14 console
# 18 constant
# 57 constantly
# 36 construction
# 10 cont
# 4 conta
# 5 contac
# 4682 contact
# 38 contacted
# 4 contained
# 6 container
# 9 contents
# 9 continually
# 16 continue
# 7 continued
# 30 continues
# 39 continuously
# 43 contractor
# 5 contractors
# 151 control
# 6 controlled
# 26 controller
# 21 controls
# 15 convenience
# 11 convert
# 5 converted
# 4 convocation
# 5 cook
# 65 cool
# 8 cooled
# 53 cooler
# 4 coolers
# 171 cooling
# 131 coor
# 9 coordinate
# 12 coordination
# 13 coordinator
# 7 coow
# 14 copies
# 10 copper
# 21 copy
# 25 cord
# 14 cords
# 26 core
# 7 cores
# 10 cork
# 121 corner
# 7 corners
# 4 corr
# 50 correct
# 5 corrected
# 10 correction
# 62 correctly
# 3 corresponding
# 70 corridor
# 6 corroded
# 3 cory
# 23 cost
# 3 costs
# 6 cottonwood
# 29 couch
# 380 could
# 6 council
# 5 count
# 37 counter
# 7 counters
# 80 couple
# 3 coupling
# 3 course
# 19 court
# 16 courtney
# 7 courts
# 39 courtyard
# 3 couty
# 19 cove
# 122 cover
# 23 covered
# 9 covering
# 31 covers
# 11 cowden
# 3 cowdn
# 119 cozens
# 27 cp
# 49 cpcom
# 19 cpmg
# 5 cr
# 3 cra
# 23 crack
# 53 cracked
# 14 cracks
# 4 craft
# 8 craig
# 3 crane
# 10 cranford
# 4 crash
# 13 crawling
# 3 cream
# 65 create
# 20 created
# 3 creates
# 14 creating
# 4 creativity
# 3 credit
# 32 crew
# 5 crhl
# 13 crickets
# 13 critical
# 3 crocker
# 7 cronk
# 26 cronkite
# 5 crooked
# 5 crouch
# 3 crow
# 3 cruz
# 3 crystal
# 52 csac
# 33 csb
# 3 csj
# 3 ctr
# 9 ctrpt
# 11 cube
# 18 cubicle
# 7 cubicles
# 3 cunningham
# 3 curbs
# 21 current
# 110 currently
# 21 curtain
# 8 curtains
# 3 cushing
# 5 cushion
# 5 cushions
# 50 custodial
# 9 custodian
# 6 custodians
# 34 customer
# 6 customers
# 75 cut
# 3 cwdn
# 12 cwp
# 7 cwpc
# 12 cycle
# 3 cycled
# 4 cycling
# 26 cylinder
# 14 cylinders
# 7 cynthia
# 3 cyr
# 20 da
# 3 dad
# 120 daily
# 4 dak
# 13 dale
# 3 dallas
# 165 damage
# 91 damaged
# 24 damages
# 36 damon
# 10 damp
# 5 damper
# 4 dampers
# 35 dan
# 5 dana
# 5 dance
# 3 danforth
# 4 danger
# 7 dangerous
# 3 dani
# 21 daniel
# 3 daniella
# 18 danielle
# 4 danny
# 6 daphne
# 3 daprato
# 48 dark
# 7 das
# 5 dash
# 8 data
# 122 date
# 16 dated
# 3 dates
# 7 dauscher
# 8 dave
# 35 david
# 14 davis
# 7 daw
# 6 dawn
# 125 day
# 86 days
# 18 db
# 3 dc
# 4 dca
# 19 dcb
# 4 dce
# 40 dd
# 4 dds
# 18 de
# 59 dead
# 30 deadbolt
# 10 deadline
# 5 deal
# 19 dean
# 6 deanna
# 3 deans
# 5 dear
# 3 debbie
# 3 debby
# 3 deborah
# 20 debris
# 7 dec
# 7 decal
# 44 decals
# 15 december
# 5 decided
# 10 deck
# 3 decor
# 106 decorative
# 3 decrease
# 3 dede
# 10 dedicated
# 26 deep
# 15 deferred
# 5 definitely
# 8 deg
# 8 degree
# 145 degrees
# 48 del
# 4 delay
# 14 deliver
# 17 delivered
# 6 delivery
# 6 demo
# 7 den
# 8 dent
# 5 dented
# 5 deodorize
# 3 deodorized
# 3 depar
# 3 departmen
# 210 department
# 6 departments
# 3 depot
# 15 dept
# 3 derek
# 524 description
# 9 desert
# 67 design
# 3 designated
# 330 desk
# 28 desks
# 4 desktop
# 4 desperately
# 6 despite
# 7 destination
# 4 destroyed
# 10 detached
# 4 detail
# 51 details
# 62 detector
# 13 detectors
# 3 detergent
# 3 deteriorating
# 12 determine
# 8 determined
# 3 dev
# 4 development
# 12 device
# 7 devices
# 19 devil
# 3 devils
# 3 df
# 16 dg
# 5 dgh
# 3 dgp
# 5 dgr
# 3 dgu
# 8 dh
# 3 dhhl
# 30 dho
# 5 dhwpmp
# 58 di
# 4 diagnose
# 5 diagnostic
# 6 dial
# 5 diamond
# 11 diana
# 8 diane
# 8 dianna
# 13 dickey
# 3 dickie
# 6 die
# 5 died
# 3 diesel
# 7 dietmeyer
# 66 different
# 46 difficult
# 4 difficulty
# 15 diffuser
# 7 diffusers
# 4 dij
# 33 dim
# 10 dimeb
# 4 dimmer
# 12 dinib
# 30 dining
# 3 dinner
# 5 diploma
# 54 direct
# 31 directly
# 21 director
# 26 dirt
# 111 dirty
# 4 dis
# 4 disability
# 7 disable
# 6 disabled
# 4 disassembled
# 6 disc
# 4 discharge
# 19 disconnect
# 12 disconnected
# 5 discount
# 3 discover
# 18 discovered
# 21 discovery
# 7 discuss
# 4 discussed
# 4 discussion
# 12 discvry
# 11 disgusting
# 23 dish
# 10 dishes
# 56 dishwasher
# 3 disp
# 408 dispatch
# 659 dispatched
# 5 dispatching
# 64 dispenser
# 20 dispensers
# 4 dispensing
# 23 display
# 60 disposal
# 6 dispose
# 4 distracting
# 4 ditore
# 4 diverter
# 8 dixie
# 78 dj
# 4 djk
# 7 dk
# 4 dkc
# 9 dkt
# 4 dku
# 9 dl
# 41 dm
# 5 dmd
# 96 dn
# 27 dock
# 7 document
# 10 dodd
# 9 doesnt
# 8 dog
# 4 dollies
# 4 dom
# 18 dome
# 29 domestic
# 129 done
# 6 donna
# 4 dont
# 1783 door
# 5 doorbell
# 7 doorknob
# 343 doors
# 12 doorway
# 8 doris
# 562 dorm
# 33 double
# 8 dowdy
# 8 downs
# 6 downstairs
# 18 downtown
# 27 dr
# 11 drag
# 4 dragging
# 561 drain
# 16 drainage
# 4 drained
# 105 draining
# 4 draino
# 71 drains
# 65 drawer
# 31 drawers
# 45 dresser
# 4 dressing
# 7 dried
# 11 drier
# 6 drill
# 4 drilled
# 143 drinking
# 36 drip
# 86 dripping
# 11 drips
# 70 drive
# 13 driver
# 6 driving
# 27 drop
# 25 dropped
# 5 dropping
# 10 droppings
# 6 drops
# 4 drum
# 31 dry
# 51 dryer
# 6 dryers
# 5 drying
# 34 drywall
# 23 ds
# 5 dt
# 6 dtpc
# 22 duane
# 10 ducey
# 28 duct
# 4 ductwork
# 122 due
# 5 dugan
# 4 dugout
# 4 dump
# 5 dumped
# 14 dumpster
# 6 duncan
# 4 dunn
# 4 dunphy
# 30 duplicate
# 4 duration
# 5 durham
# 30 dust
# 6 dusted
# 9 dustin
# 8 duty
# 7 dw
# 387 dx
# 4 dying
# 5 dylan
# 35 ea
# 5 eagle
# 25 earlier
# 57 earliest
# 20 early
# 4 ease
# 7 easily
# 361 east
# 5 eastern
# 4 easy
# 16 eb
# 11 ec
# 25 eca
# 15 ecb
# 5 ecc
# 25 ecd
# 7 ece
# 4 ecee
# 20 ecf
# 61 ecg
# 68 ed
# 25 edb
# 11 eddie
# 9 edge
# 4 edges
# 4 edging
# 662 edu
# 20 education
# 7 ee
# 22 ef
# 6 effective
# 7 efga
# 9 efu
# 6 eg
# 5 eggs
# 43 eh
# 12 ehfi
# 8 ehs
# 5 ei
# 54 either
# 53 ejector
# 9 ejs
# 4 eka
# 54 el
# 4 elbow
# 67 electric
# 179 electrical
# 34 electrician
# 15 electricians
# 15 electricity
# 5 electronics
# 84 elev
# 492 elevator
# 54 elevators
# 5 elisabeth
# 10 elizabeth
# 4 ellen
# 54 elliott
# 27 else
# 17 em
# 5 ema
# 5 emai
# 1529 email
# 44 emailed
# 4 emb
# 135 emergency
# 4 emgen
# 10 emily
# 4 emission
# 15 emissions
# 11 emmons
# 56 employee
# 6 employees
# 25 emptied
# 55 empty
# 193 ems
# 7 en
# 129 end
# 4 ended
# 10 ends
# 6 energy
# 7 eng
# 9 engage
# 9 engine
# 28 engineering
# 5 england
# 6 engr
# 8 engrained
# 15 engrc
# 36 enough
# 6 enrique
# 23 ensure
# 9 ent
# 52 enter
# 14 entered
# 25 entering
# 4 enters
# 89 entire
# 4 entirely
# 196 entrance
# 19 entrapment
# 9 entries
# 840 entry
# 4 entryway
# 11 environmental
# 6 enzyme
# 23 eo
# 5 eob
# 45 eoy
# 81 eq
# 1349 equipment
# 6 er
# 4 erase
# 81 erc
# 16 eric
# 7 erika
# 9 erin
# 4 erix
# 4 error
# 17 escort
# 7 escutcheon
# 5 esli
# 20 especially
# 21 esperti
# 7 espinoza
# 7 essex
# 45 est
# 240 estimate
# 6 estimated
# 4 eta
# 16 etc
# 59 ethernet
# 5 ev
# 4 evacuation
# 8 evaluate
# 7 evanoff
# 10 evans
# 4 evap
# 20 evaporative
# 5 evelyn
# 86 even
# 22 evening
# 288 event
# 19 events
# 7 eventually
# 18 ever
# 89 every
# 5 everyday
# 6 everyone
# 22 everything
# 13 everywhere
# 8 ex
# 19 exact
# 10 exactly
# 5 example
# 6 exceeded
# 5 except
# 4 excess
# 9 excessive
# 5 exchange
# 25 exchanger
# 5 exf
# 437 exhaust
# 51 existing
# 4 exists
# 155 exit
# 5 exiting
# 4 exits
# 12 expansion
# 27 expected
# 6 expensive
# 4 experiencing
# 6 experiments
# 4 expired
# 4 explained
# 18 exposed
# 72 ext
# 15 extension
# 189 exterior
# 5 extermination
# 4 exterminator
# 12 external
# 13 extinguisher
# 36 extra
# 6 extract
# 13 extraction
# 5 extreme
# 91 extremely
# 13 eye
# 20 fa
# 47 fab
# 4 fabric
# 7 fabricate
# 38 fac
# 7 face
# 112 facilities
# 16 facility
# 39 facing
# 103 facman
# 10 facp
# 6 fact
# 77 faculty
# 18 failed
# 4 fails
# 15 failure
# 9 fairly
# 4 faith
# 36 fall
# 51 fallen
# 63 falling
# 5 falls
# 4 familiar
# 21 family
# 594 fan
# 26 fans
# 46 far
# 17 fargo
# 63 farmer
# 10 farrington
# 9 farthest
# 9 fast
# 164 faucet
# 20 faucets
# 11 fault
# 4 faultner
# 6 faulty
# 9 fb
# 15 fc
# 9 fcu
# 27 fd
# 4 fdg
# 16 fdj
# 4 fdr
# 11 feb
# 12 february
# 6 feces
# 6 fedele
# 4 fee
# 9 feed
# 4 feeder
# 25 feel
# 20 feels
# 17 feet
# 68 fell
# 4 felt
# 4 female
# 12 fence
# 21 fernandez
# 5 fesler
# 18 ffd
# 5 ffg
# 24 fh
# 14 fi
# 9 fidler
# 13 field
# 12 fields
# 7 fifth
# 12 figure
# 4 figured
# 21 file
# 7 filed
# 17 filing
# 23 fill
# 26 filled
# 10 filler
# 22 filling
# 13 fills
# 174 filter
# 44 filters
# 6 filthy
# 8 final
# 4 finally
# 4 finals
# 5 financial
# 44 find
# 8 finding
# 7 findings
# 47 fine
# 10 finish
# 12 finished
# 418 fire
# 284 first
# 22 fit
# 7 fitness
# 5 fitting
# 7 fittings
# 17 five
# 345 fix
# 254 fixed
# 18 fixing
# 102 fixture
# 42 fixtures
# 22 fj
# 4 fk
# 74 fl
# 17 flag
# 48 flags
# 4 flapper
# 5 flash
# 11 flashing
# 17 flat
# 4 flattened
# 4 fleet
# 12 fleetwood
# 8 fletcher
# 4 flex
# 4 flicker
# 39 flickering
# 8 flickers
# 6 flies
# 7 flip
# 6 flipped
# 4 flo
# 10 float
# 24 flood
# 38 flooded
# 81 flooding
# 10 floods
# 1737 floor
# 16 flooring
# 105 floors
# 15 flores
# 16 florescent
# 58 flow
# 15 flowing
# 38 floyd
# 44 flr
# 4 flrs
# 10 fluid
# 35 fluorescent
# 172 flush
# 52 flushed
# 5 flusher
# 12 flushes
# 87 flushing
# 10 flying
# 12 fm
# 7 fn
# 10 fo
# 33 fob
# 5 focus
# 4 folding
# 5 folks
# 26 follow
# 4 followed
# 101 following
# 12 follows
# 43 food
# 13 foot
# 24 football
# 13 force
# 4 forced
# 6 ford
# 6 forest
# 9 forgot
# 4 fork
# 37 form
# 7 former
# 4 formerly
# 5 forms
# 5 forth
# 4 forum
# 21 forward
# 4 forwarded
# 5 foul
# 193 found
# 6 foundation
# 322 fountain
# 13 fountains
# 26 four
# 20 fourth
# 6 foyer
# 20 fr
# 88 frame
# 6 frames
# 9 francisco
# 22 frank
# 7 fred
# 16 free
# 4 freeze
# 36 freezer
# 33 freezing
# 25 freight
# 10 frequency
# 8 frequently
# 4 fresh
# 4 freshii
# 104 friday
# 47 fridge
# 381 front
# 4 frontczak
# 10 frozen
# 4 fruit
# 7 fsst
# 7 ft
# 13 fuel
# 8 fuentes
# 102 full
# 25 fully
# 22 fulton
# 29 fume
# 4 fumigate
# 18 function
# 24 functional
# 52 functioning
# 5 fund
# 11 funded
# 36 funding
# 8 furnace
# 6 furnish
# 78 furniture
# 6 furthest
# 18 fuse
# 4 fuses
# 16 future
# 28 fy
# 51 ga
# 7 gabe
# 24 gabriel
# 6 gail
# 6 gain
# 5 gal
# 5 gallery
# 4 galvin
# 38 game
# 8 gaming
# 53 gammage
# 6 gap
# 13 garage
# 67 garbage
# 11 garcia
# 19 garden
# 5 gary
# 44 gas
# 7 gasket
# 5 gaskets
# 90 gate
# 21 gates
# 4 gator
# 5 gauge
# 13 gave
# 11 gavin
# 7 gayla
# 12 gayle
# 11 gb
# 7 gc
# 9 gch
# 10 ge
# 7 gear
# 89 general
# 5 generated
# 91 generator
# 5 genie
# 68 george
# 351 get
# 57 gets
# 116 getting
# 27 gf
# 4 gfci
# 8 gfi
# 5 ggk
# 30 ggma
# 7 gh
# 7 ghall
# 5 giant
# 6 gic
# 11 gill
# 18 gillespie
# 15 gina
# 4 girls
# 35 give
# 24 given
# 4 gives
# 12 giving
# 4 gj
# 5 gk
# 46 gkg
# 5 gkk
# 6 gl
# 73 glass
# 6 glendale
# 7 global
# 5 glue
# 12 glued
# 18 gm
# 154 gmail
# 47 gmm
# 83 gn
# 162 go
# 46 goes
# 156 going
# 8 gold
# 26 goldwater
# 14 golf
# 37 gone
# 4 gonfalons
# 8 gonzalez
# 101 good
# 22 gorman
# 10 gorski
# 44 got
# 17 gotten
# 10 governor
# 4 grab
# 18 grabarec
# 9 grad
# 11 graduate
# 16 grady
# 22 graffiti
# 4 grand
# 20 grant
# 11 grass
# 5 grassy
# 4 grate
# 7 gravel
# 12 gray
# 12 grease
# 48 great
# 27 greatly
# 67 green
# 7 greenhouse
# 4 greetings
# 71 greg
# 22 gregory
# 5 grey
# 14 grid
# 9 grill
# 4 grind
# 13 grinding
# 7 gross
# 40 ground
# 48 grounds
# 23 group
# 5 groups
# 27 growing
# 33 growth
# 10 grzyb
# 5 guadalupe
# 7 guard
# 4 guardiola
# 51 guckian
# 4 guess
# 13 guest
# 7 guests
# 11 gum
# 5 gupta
# 4 gushing
# 9 guy
# 25 guys
# 4 gw
# 105 gwc
# 14 gym
# 4 gymnastics
# 13 ha
# 7 haa
# 5 hadden
# 12 hadley
# 37 haen
# 5 haile
# 10 hair
# 51 half
# 10 halfway
# 453 hall
# 9 halls
# 296 hallway
# 18 hallways
# 7 hammer
# 53 hand
# 52 handicap
# 19 handicapped
# 230 handle
# 5 handled
# 640 handler
# 12 handlers
# 18 handles
# 4 handley
# 10 handling
# 7 hands
# 55 hang
# 59 hanging
# 11 hannah
# 24 hansen
# 12 happen
# 26 happened
# 15 happening
# 10 happens
# 8 happy
# 62 hard
# 4 harding
# 31 hardware
# 7 harl
# 8 harris
# 12 hassan
# 23 hassayampa
# 12 hassy
# 7 hassyampa
# 4 hatch
# 237 hav
# 38 haveastfd
# 5 havf
# 13 havg
# 15 havh
# 5 havwestfrontdesk
# 21 hawley
# 181 hayden
# 6 hays
# 26 hazard
# 5 hazardous
# 6 hazel
# 17 hb
# 45 hc
# 216 hd
# 71 head
# 4 header
# 12 heads
# 63 health
# 13 hear
# 11 heard
# 124 heat
# 86 heater
# 5 heaters
# 9 heather
# 30 heating
# 6 heavily
# 18 heavy
# 9 height
# 10 held
# 154 hello
# 186 help
# 30 henry
# 4 hensley
# 5 herberger
# 24 herdan
# 12 herrera
# 6 hess
# 16 hetzel
# 7 hey
# 59 hf
# 10 hh
# 98 hi
# 5 hif
# 87 high
# 13 higher
# 14 highest
# 5 highly
# 6 hill
# 381 hinge
# 33 hinges
# 5 hintze
# 13 hit
# 9 hitting
# 6 hive
# 6 hj
# 12 hja
# 20 hk
# 5 hl
# 5 hlths
# 13 hm
# 6 hn
# 5 ho
# 104 hobbs
# 13 hoffman
# 23 hold
# 365 holder
# 3 holders
# 19 holding
# 7 holds
# 103 hole
# 63 holes
# 4 holidays
# 3 holloway
# 5 holly
# 29 home
# 3 homeless
# 5 homework
# 7 honor
# 16 honors
# 5 honorshallfrontdesk
# 41 hood
# 4 hoods
# 12 hook
# 11 hooks
# 4 hoop
# 11 hope
# 4 hopefully
# 13 hoping
# 4 horizon
# 5 horizontal
# 4 horn
# 9 horrible
# 34 hose
# 4 hoses
# 11 hosting
# 476 hot
# 3 hotmail
# 5 hotter
# 15 hour
# 57 hours
# 677 house
# 5 housed
# 3 household
# 6 houses
# 63 housing
# 13 howell
# 54 however
# 12 hp
# 29 hr
# 3 hrs
# 4 hs
# 6 hsb
# 3 huaixiao
# 25 hub
# 8 hudson
# 3 huff
# 5 huffman
# 4 hufford
# 22 huge
# 4 human
# 15 humid
# 8 humidifier
# 19 humidity
# 6 humming
# 43 hung
# 3 hurd
# 4 hurt
# 4 husein
# 325 hvac
# 4 hw
# 8 hx
# 5 hydrant
# 6 hydraulic
# 5 ia
# 5 ian
# 43 ib
# 6 ibf
# 3 ic
# 56 ice
# 3 icloud
# 84 id
# 8 idea
# 8 identification
# 8 identified
# 3 idf
# 3 ie
# 6 iem
# 6 ig
# 3 ignore
# 4 ignored
# 53 ii
# 6 iia
# 3 iii
# 3 ij
# 4 ikf
# 3 ileyn
# 3 illuminating
# 11 im
# 4 image
# 37 imio
# 24 immediate
# 51 immediately
# 10 impact
# 8 impacted
# 20 important
# 4 impossible
# 3 improper
# 4 improved
# 8 inb
# 12 inc
# 21 inch
# 8 inches
# 4 incident
# 14 include
# 6 includes
# 25 including
# 9 incoming
# 3 inconvenience
# 3 incorrect
# 29 increase
# 11 increased
# 4 incredibly
# 3 indian
# 3 indicate
# 14 indicated
# 4 indicating
# 9 indicator
# 18 individual
# 4 individuals
# 3 indoor
# 12 infestation
# 28 info
# 12 inform
# 153 information
# 27 informed
# 4 initial
# 6 initially
# 9 initiate
# 3 injury
# 4 inlet
# 16 inner
# 9 innovation
# 7 inoperable
# 6 insects
# 7 insert
# 210 inside
# 118 inspect
# 24 inspected
# 1702 inspection
# 10 inspections
# 4 inspector
# 5 inst
# 207 install
# 31 installation
# 115 installed
# 12 installing
# 19 instead
# 10 institute
# 12 instructions
# 16 instructor
# 3 instruments
# 3 insufficient
# 5 insulate
# 3 insulated
# 15 insulation
# 62 insurance
# 20 insure
# 3 int
# 6 intake
# 8 intds
# 10 intdsa
# 33 intdsb
# 15 interdisciplinary
# 4 interface
# 4 interfering
# 64 interior
# 3 interment
# 6 intermittent
# 6 intermittently
# 3 intermountain
# 21 internal
# 7 international
# 42 internet
# 7 inventory
# 55 investigate
# 4 investigated
# 21 invoice
# 5 invoices
# 5 involved
# 13 io
# 3 irene
# 29 irish
# 12 iron
# 94 irrigation
# 63 isaac
# 4 island
# 3 isnt
# 3 isolate
# 3 isolated
# 13 isolation
# 9 issac
# 535 issue
# 36 issued
# 113 issues
# 255 istb
# 13 item
# 48 items
# 8 iv
# 3 ivan
# 3 ix
# 12 ja
# 15 jack
# 21 jacob
# 26 jacobs
# 10 jam
# 43 james
# 9 jamie
# 30 jammed
# 8 jan
# 4 janet
# 5 janice
# 4 janina
# 12 janitor
# 12 janitorial
# 8 janitors
# 19 janna
# 21 january
# 4 jared
# 15 jason
# 7 jb
# 24 jbreeze
# 93 jc
# 13 jeanette
# 129 jeff
# 36 jeffrey
# 34 jenna
# 26 jennifer
# 117 jesse
# 24 jessica
# 5 jesus
# 5 jf
# 10 jg
# 6 jh
# 18 jhk
# 10 jill
# 32 jim
# 6 jimenez
# 15 jimmy
# 10 jj
# 6 jk
# 6 jl
# 16 jm
# 19 jo
# 31 job
# 77 joe
# 24 joel
# 129 john
# 3 johnny
# 6 johns
# 22 johnson
# 8 joint
# 7 jojoba
# 5 jon
# 4 jonah
# 7 jonathan
# 11 jones
# 5 joni
# 7 jordan
# 16 jose
# 10 joseph
# 8 josephine
# 36 josh
# 18 joshua
# 35 juan
# 26 judd
# 18 judy
# 5 julia
# 4 julian
# 29 julie
# 28 july
# 4 jun
# 20 june
# 9 juniper
# 4 justice
# 16 justin
# 8 ka
# 10 kahlea
# 5 kappa
# 4 kappes
# 12 karen
# 4 karl
# 4 karr
# 4 karsten
# 4 kathi
# 13 kathleen
# 17 kathy
# 5 katie
# 6 katrina
# 4 kawasaki
# 10 kb
# 16 kc
# 7 ke
# 5 kearney
# 55 keep
# 15 keeping
# 74 keeps
# 4 kellerman
# 4 kelley
# 7 kelly
# 6 kelsey
# 20 kelsie
# 4 ken
# 40 kennedy
# 5 kenny
# 19 kenzalia
# 10 kept
# 11 kern
# 31 kevin
# 2164 key
# 9 keyboard
# 12 keyed
# 267 keys
# 4 kg
# 4 kh
# 42 khalil
# 5 khan
# 15 kick
# 8 kicked
# 5 killed
# 6 kim
# 22 kimberly
# 14 kind
# 4 kinda
# 17 king
# 4 kirsten
# 10 kit
# 326 kitchen
# 3 kitchenette
# 7 kj
# 7 kk
# 5 kl
# 12 klackle
# 3 klein
# 14 klonowski
# 5 km
# 17 kmj
# 45 kn
# 3 knee
# 5 knight
# 46 knob
# 5 knobs
# 3 knock
# 7 knocked
# 169 know
# 4 known
# 3 knows
# 9 knox
# 4 ko
# 3 kohler
# 7 kolby
# 6 konopisos
# 28 kopp
# 7 kr
# 7 kreutz
# 9 kris
# 7 kristen
# 4 kristi
# 35 kristin
# 5 kristine
# 7 kristopher
# 3 krum
# 4 kumar
# 4 kunz
# 25 ky
# 73 kyle
# 47 la
# 168 lab
# 11 label
# 12 labeled
# 5 labelle
# 807 labor
# 3 laboratories
# 3 laboratory
# 24 labs
# 5 lack
# 4 lad
# 13 ladder
# 36 ladies
# 9 lai
# 8 laid
# 7 laminate
# 187 lamp
# 156 lamps
# 11 lan
# 11 landing
# 14 landscape
# 9 landscaping
# 5 lane
# 7 language
# 4 laptop
# 131 large
# 13 larger
# 3 larracas
# 52 larry
# 3 larson
# 4 larue
# 14 las
# 3 lasman
# 163 last
# 3 lastly
# 3 lat
# 68 latch
# 3 latches
# 22 latching
# 5 late
# 13 later
# 6 lateral
# 4 launch
# 73 laundry
# 37 laura
# 6 lauren
# 7 laurie
# 39 law
# 3 lawlb
# 24 lawn
# 3 lay
# 6 laying
# 7 lb
# 8 lbho
# 3 lbs
# 10 lc
# 3 lca
# 7 ld
# 4 le
# 4 lead
# 32 leading
# 16 leads
# 7 leah
# 390 leak
# 7 leakage
# 16 leaked
# 530 leaking
# 88 leaks
# 16 leaky
# 5 leary
# 30 least
# 22 leave
# 10 leaves
# 18 leaving
# 20 lecture
# 7 led
# 20 lee
# 303 left
# 10 leg
# 10 legs
# 5 leisy
# 5 lemon
# 4 length
# 9 lens
# 5 leo
# 19 leroy
# 14 less
# 103 let
# 4 lets
# 4 letters
# 8 letting
# 189 level
# 5 levels
# 22 lever
# 9 lf
# 3 lfb
# 5 lg
# 4 lga
# 3 lha
# 7 li
# 41 lib
# 5 libby
# 172 library
# 7 lid
# 214 life
# 35 lift
# 4 lifted
# 3 lifting
# 1159 light
# 38 lightbulb
# 14 lightbulbs
# 247 lighting
# 520 lights
# 445 like
# 15 likely
# 4 lillie
# 4 limb
# 4 limit
# 7 lind
# 35 linda
# 5 lindsay
# 814 line
# 4 liners
# 19 lines
# 11 link
# 19 liquid
# 61 lisa
# 41 list
# 11 listed
# 7 lit
# 5 literature
# 52 little
# 24 live
# 89 living
# 15 lj
# 32 lm
# 21 ln
# 7 lo
# 14 load
# 21 loading
# 7 lobbies
# 138 lobby
# 5 loc
# 3 local
# 13 locate
# 173 located
# 159 location
# 9 locations
# 716 lock
# 125 locked
# 51 locker
# 5 lockers
# 33 locking
# 3 lockout
# 3 lockouts
# 59 locks
# 14 lockset
# 13 lockshop
# 10 loft
# 18 lofted
# 5 log
# 3 logan
# 59 long
# 65 longer
# 197 look
# 49 looked
# 24 looking
# 59 looks
# 10 looo
# 88 loop
# 194 loose
# 7 lopez
# 5 lord
# 4 loren
# 21 lori
# 6 lose
# 7 losing
# 5 loss
# 145 lost
# 107 lot
# 20 lots
# 5 lou
# 80 loud
# 7 loudly
# 70 lounge
# 6 lounges
# 5 love
# 85 low
# 148 lower
# 51 lowered
# 6 lowering
# 4 lowes
# 6 lowest
# 4 loya
# 5 lp
# 5 ls
# 122 lsa
# 4 lsb
# 103 lsc
# 5 lsd
# 184 lse
# 3 lto
# 4 lu
# 6 lubing
# 5 lubricate
# 3 lucas
# 6 lucero
# 12 luczak
# 25 luis
# 42 luna
# 9 lunch
# 3 luncheon
# 4 lupampa
# 4 lupe
# 6 luquez
# 4 lyceum
# 4 lynda
# 3 lynn
# 50 mac
# 4 maccleary
# 99 machine
# 13 machines
# 71 made
# 7 madison
# 3 maggie
# 5 magnetic
# 22 mahalov
# 89 mail
# 24 mailbox
# 5 mailboxes
# 4 mailto
# 242 main
# 4 mainly
# 5 maint
# 636 maintenance
# 3 maintenence
# 19 major
# 198 make
# 13 maker
# 39 makes
# 110 making
# 4 male
# 8 malfunction
# 12 malfunctioning
# 62 mall
# 3 malloy
# 16 man
# 4 managed
# 32 management
# 32 manager
# 8 manasse
# 3 manny
# 5 manually
# 5 manuel
# 39 many
# 9 manzanita
# 7 manzy
# 8 map
# 9 marasco
# 37 marc
# 5 marcella
# 27 march
# 21 marcia
# 6 margaret
# 10 maria
# 3 mariah
# 3 mariana
# 11 marie
# 3 marino
# 47 mark
# 18 marked
# 6 marker
# 12 market
# 3 marketing
# 4 marketplace
# 4 markley
# 4 markovich
# 16 marks
# 5 maroon
# 24 marquez
# 5 marsh
# 5 marshal
# 4 marshall
# 3 marshals
# 39 martin
# 19 martinez
# 12 marturano
# 12 mary
# 10 massara
# 45 master
# 4 mastine
# 7 mat
# 17 match
# 15 material
# 35 materials
# 5 mates
# 4 mats
# 13 matt
# 26 matter
# 44 matthew
# 17 matthews
# 24 mattress
# 6 mau
# 21 max
# 209 may
# 23 maybe
# 12 mb
# 11 mbb
# 7 mc
# 4 mcadams
# 11 mcc
# 23 mcclintock
# 35 mccord
# 15 mcd
# 23 mcent
# 4 mcgowen
# 35 mcintyre
# 13 mckenzie
# 10 mckinney
# 4 mcl
# 15 mcrd
# 4 mcwhorter
# 13 md
# 5 meant
# 55 mechanical
# 4 mechanics
# 25 mechanism
# 15 media
# 5 medicine
# 12 medium
# 50 meet
# 63 meeting
# 5 meetings
# 5 meets
# 5 meg
# 11 megan
# 4 mehalic
# 6 meland
# 16 melanie
# 8 melissa
# 33 member
# 6 members
# 20 memorial
# 208 men
# 58 mens
# 4 mention
# 10 mentioned
# 9 merc
# 35 mercado
# 12 meredith
# 12 mesquite
# 10 mess
# 40 message
# 7 messy
# 4 met
# 49 metal
# 4 metasys
# 12 meter
# 4 metzger
# 6 mezzanine
# 6 mfo
# 18 mg
# 6 mh
# 4 mhall
# 4 mhc
# 8 mi
# 51 michael
# 24 michele
# 12 michelle
# 45 microwave
# 9 mid
# 59 middle
# 4 midnight
# 7 midstate
# 19 mie
# 21 mif
# 50 might
# 319 mike
# 14 mildew
# 27 mileage
# 6 miller
# 4 mills
# 5 min
# 9 mine
# 12 mini
# 4 minimum
# 10 minor
# 7 minute
# 52 minutes
# 52 mirror
# 4 mirrors
# 5 miscellaneous
# 4 missed
# 327 missing
# 4 mixer
# 8 mj
# 5 mk
# 11 ml
# 5 mlf
# 38 mm
# 18 mn
# 48 mna
# 13 mngh
# 4 mnghal
# 181 mo
# 5 mode
# 10 model
# 8 modem
# 8 modify
# 7 modular
# 12 moeur
# 11 moh
# 6 mohave
# 5 mok
# 90 mold
# 4 molding
# 6 moldy
# 6 molina
# 4 moment
# 6 mona
# 73 monday
# 6 monica
# 15 monitor
# 5 monroe
# 35 month
# 1351 monthly
# 26 months
# 8 moo
# 12 moore
# 35 mop
# 17 mopped
# 4 mora
# 6 moreno
# 5 morgan
# 201 morning
# 18 mosquitoes
# 4 mosquitos
# 12 motion
# 62 motor
# 5 motors
# 33 mount
# 25 mounted
# 3 mounting
# 12 mouse
# 3 mov
# 190 move
# 138 moved
# 24 movers
# 11 moves
# 80 moving
# 8 mower
# 7 mowing
# 10 mpac
# 3 mr
# 26 mrr
# 3 mrs
# 3 msb
# 4 mst
# 135 mu
# 137 much
# 5 mulkey
# 4 mullion
# 4 multi
# 91 multiple
# 14 muni
# 4 munoz
# 6 murdock
# 5 murillo
# 17 muscara
# 20 museum
# 74 music
# 26 must
# 6 mustang
# 7 musty
# 6 mvd
# 4 mwdavis
# 2481 mwo
# 7 mx
# 12 myrna
# 8 mzgorski
# 48 na
# 3 naa
# 18 nabors
# 3 nad
# 3 nadine
# 6 nag
# 13 naig
# 6 nail
# 3 nak
# 3 nalco
# 4 nam
# 1905 name
# 8 names
# 18 nancy
# 3 nap
# 7 napa
# 4 nasty
# 6 nathan
# 101 naumann
# 50 nb
# 3 nbbklg
# 13 nbd
# 20 nbi
# 10 nbiefn
# 9 nbik
# 4 nbj
# 5 nbklfi
# 4 nbo
# 140 nc
# 7 nca
# 3 ncad
# 5 ncb
# 12 ncba
# 6 ncbg
# 3 ncc
# 6 nccbf
# 3 ncd
# 6 ncda
# 11 ncdcof
# 3 nce
# 3 nceeoe
# 3 nceigf
# 34 ncf
# 3 ncfa
# 4 ncfhhi
# 4 ncg
# 5 ncgm
# 3 ncgnhd
# 16 nchi
# 13 ncibi
# 5 ncicea
# 28 ncij
# 3 nciofc
# 4 ncj
# 22 nck
# 32 ncknan
# 5 ncl
# 6 ncmb
# 3 ncmh
# 3 ncojfa
# 373 nd
# 5 ndb
# 60 ndc
# 25 ndcijf
# 3 ndeclc
# 4 ndeol
# 3 ndgaje
# 10 ndh
# 4 ndl
# 7 ndm
# 5 ndn
# 3 ndo
# 9 ndv
# 51 ne
# 3 neafaj
# 5 neal
# 200 near
# 8 nearby
# 14 nearest
# 5 nearly
# 4 neb
# 7 nec
# 28 necessary
# 5 ned
# 4 nee
# 10 neeb
# 1162 need
# 292 needed
# 24 needing
# 1010 needs
# 3 neel
# 18 negative
# 6 nehioo
# 3 nehj
# 43 nei
# 3 neighbor
# 3 neil
# 13 neither
# 17 nek
# 4 nel
# 8 neljo
# 24 nelson
# 7 neoihb
# 4 neood
# 9 nest
# 9 net
# 20 network
# 4 neutral
# 45 never
# 460 new
# 4 newell
# 9 newly
# 4 newman
# 153 next
# 285 nf
# 24 nfa
# 4 nfaf
# 23 nfafm
# 5 nfahgm
# 5 nfb
# 3 nfbc
# 10 nfc
# 5 nfd
# 9 nfdb
# 7 nfe
# 13 nff
# 4 nfga
# 4 nfgdh
# 5 nfgi
# 4 nfgoia
# 7 nfh
# 7 nfhhbb
# 5 nfhhd
# 9 nfi
# 3 nfiiaa
# 4 nfinck
# 5 nfj
# 4 nfjeme
# 8 nfk
# 5 nfl
# 7 nfm
# 8 nfmb
# 4 nfn
# 4 nfnmfg
# 3 nfo
# 167 ng
# 17 nga
# 13 ngacak
# 3 ngahkc
# 4 ngbabo
# 8 ngg
# 6 nggfcc
# 7 ngh
# 3 nghc
# 4 ngj
# 3 ngkmgd
# 6 ngl
# 5 ngm
# 4 ngo
# 59 nh
# 6 nhbd
# 4 nhe
# 3 nhh
# 13 nhi
# 19 nhic
# 5 nhj
# 7 nhk
# 11 nhl
# 3 nho
# 93 ni
# 6 nia
# 4 nibn
# 7 nic
# 3 nicd
# 6 nice
# 10 nick
# 8 nicole
# 24 nid
# 116 night
# 6 nights
# 4 nightstand
# 9 nih
# 4 nijhj
# 3 nijm
# 26 nikole
# 18 nil
# 4 nine
# 4 nintendo
# 4 nita
# 116 nj
# 9 njc
# 6 njd
# 12 nje
# 6 njf
# 6 njg
# 8 njggo
# 22 njh
# 8 nji
# 4 njij
# 5 njj
# 4 njk
# 26 njl
# 4 njlglm
# 9 njm
# 13 njn
# 4 njnaok
# 33 njo
# 204 nk
# 5 nka
# 6 nkb
# 167 nkc
# 5 nkcfa
# 5 nkd
# 4 nkdie
# 6 nke
# 4 nkf
# 70 nkh
# 7 nki
# 5 nkj
# 5 nkmjdb
# 4 nko
# 64 nl
# 35 nlb
# 34 nld
# 7 nlg
# 50 nlgbh
# 109 nlgdf
# 6 nlggd
# 5 nli
# 10 nlj
# 130 nm
# 5 nmh
# 18 nmo
# 89 nn
# 7 nnaknj
# 6 nnd
# 8 nne
# 29 nnfek
# 5 nnh
# 13 nni
# 4 nnk
# 6 nnl
# 13 nnmmag
# 4 noa
# 8 nob
# 52 noble
# 15 nobles
# 9 noce
# 4 nod
# 99 noise
# 18 noises
# 11 noisy
# 6 noj
# 28 nolan
# 6 nolen
# 13 nomlha
# 42 non
# 14 none
# 8 noon
# 5 noriega
# 6 norma
# 35 normal
# 14 normally
# 315 north
# 15 northeast
# 9 northern
# 15 northwest
# 6 notch
# 47 note
# 9 noted
# 58 notes
# 27 nothing
# 13 notice
# 5 noticeable
# 57 noticed
# 9 notification
# 20 notified
# 15 notify
# 6 nov
# 9 novak
# 19 november
# 8 null
# 1770 number
# 24 numbers
# 5 numerous
# 7 nursing
# 4 nuts
# 16 nw
# 4 oa
# 5 oasis
# 4 ob
# 4 obama
# 11 oberlin
# 5 obk
# 5 obtain
# 15 oc
# 5 occasionally
# 6 occupancy
# 37 occupant
# 27 occupants
# 9 occupied
# 4 occupy
# 5 occurred
# 4 occurrence
# 4 occurring
# 7 oct
# 19 october
# 14 od
# 5 odd
# 27 odor
# 4 oe
# 660 office
# 4 officer
# 95 offices
# 4 official
# 17 often
# 5 og
# 5 ohj
# 4 ohms
# 78 oil
# 50 ok
# 7 okay
# 6 oked
# 7 ol
# 204 old
# 6 older
# 5 olf
# 5 oliver
# 215 olympus
# 640 one
# 24 ones
# 11 ongoing
# 11 online
# 84 onto
# 5 op
# 468 open
# 66 opened
# 16 opener
# 53 opening
# 33 opens
# 14 operate
# 4 operated
# 17 operating
# 28 operation
# 11 operational
# 31 operations
# 41 opportunity
# 5 opposite
# 5 ops
# 11 option
# 9 orange
# 446 order
# 27 ordered
# 13 orders
# 331 org
# 5 orientation
# 54 orig
# 97 original
# 4 originating
# 16 ortiz
# 4 ot
# 8 others
# 20 outage
# 13 outages
# 12 outdoor
# 22 outer
# 133 outlet
# 80 outlets
# 4 output
# 9 outs
# 394 outside
# 30 oven
# 34 overflow
# 26 overflowed
# 91 overflowing
# 11 overflows
# 47 overhead
# 6 overheating
# 50 overnight
# 4 owner
# 20 pa
# 40 pablo
# 38 pace
# 6 packard
# 4 packing
# 11 pad
# 11 padlock
# 4 padlocks
# 7 page
# 54 paid
# 407 paint
# 40 painted
# 10 painter
# 4 painters
# 34 painting
# 5 pair
# 8 palm
# 101 palo
# 6 pam
# 15 pamela
# 7 pan
# 7 pane
# 155 panel
# 27 panels
# 7 panic
# 5 pans
# 161 paper
# 6 papers
# 4 parent
# 8 park
# 63 parking
# 67 part
# 13 partial
# 15 partially
# 6 particular
# 6 particularly
# 10 partition
# 5 partitions
# 53 parts
# 13 party
# 22 pass
# 6 passage
# 24 passenger
# 53 past
# 144 patch
# 22 patched
# 6 patches
# 4 patching
# 4 pathway
# 47 patio
# 4 patricia
# 6 patrick
# 6 patron
# 4 patton
# 4 patty
# 4 paul
# 6 paulina
# 11 pay
# 5 payment
# 49 payne
# 35 payton
# 12 pb
# 6 pc
# 23 pd
# 15 pe
# 27 pebe
# 11 pebw
# 4 peel
# 13 peeling
# 8 pegg
# 7 pei
# 6 pencil
# 6 pending
# 4 penetrations
# 5 penthouse
# 75 people
# 213 per
# 9 peralta
# 24 perform
# 6 performance
# 5 performed
# 11 performing
# 6 perhaps
# 4 perimeter
# 5 periodically
# 13 perkins
# 6 perko
# 7 permanent
# 4 permit
# 21 perry
# 37 person
# 7 personal
# 10 personnel
# 54 pest
# 96 pete
# 47 peter
# 8 peterson
# 13 ph
# 7 phantom
# 10 phase
# 8 phil
# 6 phillips
# 5 pho
# 13 phoenix
# 5 phon
# 1606 phone
# 63 photo
# 36 photos
# 15 phx
# 34 physical
# 6 physics
# 5 pi
# 5 picho
# 66 pick
# 19 picked
# 4 pickens
# 12 pickup
# 4 pickupdt
# 6 pictorial
# 49 picture
# 39 pictures
# 41 piece
# 18 pieces
# 4 pile
# 19 pin
# 108 pipe
# 5 piper
# 32 pipes
# 30 piping
# 13 pit
# 7 pitch
# 11 pitchforks
# 168 pl
# 90 place
# 58 placed
# 10 placement
# 7 places
# 14 plan
# 4 planning
# 87 plant
# 8 planter
# 5 plants
# 4 plaque
# 7 plaster
# 29 plastic
# 34 plate
# 10 plates
# 4 play
# 18 playground
# 8 playstation
# 7 plaza
# 3658 please
# 4 plehn
# 29 plug
# 38 plugged
# 4 plugging
# 9 plugs
# 42 plumber
# 22 plumbers
# 202 plumbing
# 8 plummer
# 7 plunge
# 11 plunger
# 15 plus
# 4 plz
# 724 pm
# 4 pms
# 588 po
# 13 pod
# 38 point
# 12 points
# 40 pole
# 13 poles
# 23 police
# 13 policy
# 64 poly
# 9 polyfacman
# 5 polytechnic
# 104 pool
# 6 pooling
# 7 poor
# 11 pop
# 8 popped
# 11 popping
# 10 porch
# 30 port
# 7 portable
# 17 portal
# 23 porter
# 13 portion
# 20 ports
# 25 position
# 259 possible
# 50 possibly
# 27 post
# 5 posted
# 4 poster
# 5 pot
# 10 potential
# 4 pounds
# 7 poured
# 7 pouring
# 244 power
# 4 pr
# 7 pre
# 4 prefer
# 4 preferably
# 12 prep
# 15 preparation
# 8 prepare
# 11 preschool
# 12 present
# 4 presentation
# 9 president
# 8 press
# 7 pressed
# 102 pressure
# 25 pretty
# 24 prevent
# 18 preventer
# 7 preventing
# 72 prevention
# 6 prevents
# 33 previous
# 24 previously
# 5 primary
# 4 print
# 32 prior
# 32 priority
# 7 privacy
# 5 private
# 4 prj
# 26 prlta
# 110 proactive
# 13 probably
# 169 problem
# 36 problems
# 42 proceed
# 27 process
# 11 processed
# 6 proclamation
# 7 produces
# 4 producing
# 8 product
# 33 professor
# 24 program
# 4 programming
# 4 programs
# 5 progress
# 87 project
# 10 projector
# 6 projects
# 6 promenade
# 4 prongs
# 24 proper
# 247 properly
# 31 property
# 7 proposal
# 10 propped
# 4 protection
# 105 provide
# 34 provided
# 6 providing
# 8 prune
# 40 ps
# 18 psa
# 25 psb
# 26 psc
# 29 psd
# 19 pse
# 96 psf
# 62 psh
# 33 psy
# 8 psychology
# 20 psyn
# 7 pts
# 50 public
# 35 puddle
# 4 puddles
# 32 pull
# 28 pulled
# 9 pulling
# 537 pump
# 4 pumped
# 5 pumping
# 30 pumps
# 10 purchase
# 9 purchased
# 4 purple
# 16 purposes
# 43 push
# 27 pushed
# 4 pushes
# 6 pushing
# 198 put
# 15 putting
# 39 pv
# 8 pve
# 31 pvw
# 24 pyisone
# 4 qty
# 20 quad
# 5 quality
# 4 quantities
# 18 quarter
# 419 quarterly
# 4 question
# 122 questions
# 4 quick
# 38 quickly
# 33 quite
# 54 quote
# 4 ra
# 8 rachel
# 30 rack
# 8 racks
# 9 rail
# 10 railing
# 9 rails
# 32 rain
# 4 raining
# 16 rains
# 25 raise
# 26 raised
# 5 raising
# 16 ramp
# 5 ran
# 9 randomly
# 46 randy
# 8 range
# 4 rat
# 14 rate
# 4 rated
# 11 rather
# 6 rattles
# 9 rattling
# 13 ray
# 10 rb
# 4 rbf
# 5 rbg
# 5 rbh
# 231 rd
# 9 reach
# 7 reached
# 11 read
# 30 reader
# 14 reading
# 28 reads
# 44 ready
# 6 real
# 102 really
# 38 rear
# 23 reason
# 4 reasons
# 5 reassembled
# 11 reattach
# 5 reattached
# 10 rebecca
# 22 rebuild
# 6 rebuilt
# 6 receive
# 98 received
# 7 receiving
# 16 recent
# 45 recently
# 11 receptacle
# 19 reception
# 5 receptionist
# 11 recessed
# 5 recommended
# 21 record
# 4 records
# 8 recurring
# 30 recycle
# 41 recycling
# 40 red
# 4 redone
# 4 reduce
# 4 reed
# 4 reeves
# 6 ref
# 10 refer
# 11 reference
# 8 refill
# 6 refrigerant
# 59 refrigerator
# 23 regarding
# 5 regardless
# 8 regards
# 13 register
# 5 registering
# 13 registration
# 27 regular
# 9 regularly
# 7 regulator
# 4 reheat
# 19 reinstall
# 8 reinstalled
# 4 reinsulate
# 28 rekey
# 5 rekeyed
# 10 relamp
# 16 related
# 5 relay
# 12 release
# 8 relief
# 18 relocate
# 9 relocated
# 6 relocation
# 11 remain
# 5 remaining
# 10 remains
# 4 remember
# 4 remodel
# 6 remote
# 53 removal
# 236 remove
# 168 removed
# 10 removing
# 44 rene
# 13 renovation
# 5 rep
# 6 repaint
# 8 repainted
# 572 repair
# 113 repaired
# 5 repairing
# 85 repairs
# 518 repeat
# 4 repeated
# 6 repeatedly
# 755 replace
# 384 replaced
# 205 replacement
# 43 replacing
# 218 report
# 210 reported
# 23 reporting
# 31 reports
# 4 requ
# 1809 request
# 115 requested
# 318 requester
# 192 requesting
# 9 requestor
# 42 requests
# 19 require
# 36 required
# 20 requires
# 4 requiring
# 153 res
# 34 research
# 4 researcher
# 22 reservation
# 79 reset
# 3 resetting
# 3 reside
# 47 residence
# 305 resident
# 57 residential
# 65 residents
# 5 residue
# 7 reslife
# 3 resolution
# 21 resolve
# 14 resolved
# 7 resource
# 3 resources
# 5 respectfully
# 42 respond
# 16 responded
# 47 responding
# 8 response
# 9 responsible
# 4 ress
# 41 rest
# 6 restart
# 3 restarted
# 6 restaurant
# 7 restock
# 8 restoration
# 14 restore
# 10 restored
# 4 restricted
# 476 restroom
# 44 restrooms
# 9 result
# 3 resulting
# 9 results
# 5 resurface
# 3 retaining
# 6 retrieve
# 3 retrofits
# 60 return
# 27 returned
# 14 revella
# 6 reverse
# 58 review
# 3 reviewed
# 6 revised
# 9 reyes
# 3 reymundo
# 7 reynolds
# 14 rfmt
# 4 rha
# 13 rheam
# 3 rice
# 31 richard
# 4 richter
# 6 rick
# 4 ricky
# 11 rid
# 13 rider
# 12 ries
# 290 right
# 3 rim
# 24 ring
# 6 rings
# 4 rio
# 12 ripped
# 11 riser
# 4 risers
# 5 rising
# 9 risk
# 8 ritzko
# 68 rj
# 22 rl
# 107 rm
# 19 ro
# 6 roach
# 27 roaches
# 11 road
# 7 roalson
# 6 rob
# 76 robert
# 5 roberta
# 7 robertson
# 18 rock
# 3 rocks
# 24 rod
# 22 rodarte
# 6 rodriguez
# 3 rods
# 8 roger
# 3 roku
# 14 roll
# 3 rolled
# 23 roller
# 7 rolling
# 7 rollins
# 3 rolls
# 7 romero
# 4 romo
# 7 ron
# 4 rondeau
# 201 roof
# 4 roofer
# 4 roofers
# 4 roofing
# 4 roofs
# 4 rooftop
# 4909 room
# 26 roommate
# 7 roommates
# 279 rooms
# 3 roque
# 8 rosa
# 3 rose
# 3 rosewood
# 13 ross
# 28 rotate
# 5 rotation
# 5 rothermel
# 7 rotors
# 7 rotten
# 5 rotting
# 6 roughly
# 9 round
# 10 rounds
# 10 route
# 3 routed
# 15 router
# 29 routine
# 14 row
# 4 rowen
# 3 rows
# 3 roxane
# 34 rr
# 15 rss
# 3 rtu
# 17 rubber
# 10 rubbing
# 3 rug
# 3 ruined
# 53 run
# 189 running
# 30 runs
# 16 rural
# 4 rush
# 11 russell
# 8 rust
# 8 rusted
# 11 rusty
# 21 ryan
# 5 sa
# 4 sabrina
# 3 sac
# 3 sacaton
# 4 sacs
# 3 sactn
# 15 safe
# 3 safely
# 179 safety
# 10 sage
# 12 sagewood
# 4 sagging
# 118 said
# 16 sal
# 3 sala
# 3 salado
# 4 sales
# 5 salt
# 6 salvage
# 19 sam
# 4 sama
# 13 samantha
# 17 sammy
# 4 sample
# 13 sampled
# 4 samples
# 5 sampling
# 6 samuel
# 42 san
# 10 sanca
# 9 sanchez
# 5 sand
# 19 sandoval
# 6 sandra
# 14 sands
# 17 sanitary
# 7 sanitize
# 5 sanitized
# 4 sanpablofrontdesk
# 10 santa
# 5 santan
# 11 santn
# 30 sara
# 11 sarah
# 7 sat
# 4 satellite
# 3 saturated
# 3 saturating
# 104 saturday
# 14 saw
# 8 say
# 15 saying
# 4 sayma
# 3 sayres
# 43 says
# 9 sb
# 5 sc
# 5 scan
# 4 scanner
# 7 sch
# 7 schaefer
# 61 schedule
# 43 scheduled
# 5 scheduling
# 3 schmidt
# 59 school
# 18 schwada
# 4 sci
# 36 science
# 25 sciences
# 48 scob
# 4 sconce
# 118 scope
# 10 scot
# 98 scott
# 3 scottsdale
# 3 scotty
# 4 scrape
# 4 scraping
# 4 scratch
# 4 scratched
# 5 scratches
# 3 screeching
# 33 screen
# 6 screens
# 21 screw
# 6 screwed
# 43 screws
# 4 scruggs
# 6 scuff
# 4 sculpture
# 6 sd
# 63 sdfc
# 4 sdfcd
# 12 sdfct
# 37 sds
# 12 sdsp
# 14 sdv
# 7 se
# 32 seal
# 8 sealed
# 3 sealing
# 7 seals
# 20 sean
# 4 search
# 4 season
# 23 seasonal
# 76 seat
# 7 seating
# 11 seats
# 4 sec
# 167 second
# 3 secondary
# 12 seconds
# 6 secret
# 54 section
# 3 sections
# 37 secure
# 21 secured
# 8 securely
# 5 securing
# 129 security
# 274 see
# 5 seeing
# 59 seem
# 10 seemed
# 142 seems
# 16 seen
# 7 seeping
# 6 seized
# 8 select
# 6 selected
# 11 self
# 7 semeon
# 26 semester
# 64 semi
# 321 send
# 7 sending
# 4 sense
# 7 sensitive
# 39 sensor
# 131 sent
# 11 separate
# 10 separator
# 7 sept
# 17 september
# 174 ser
# 14 sercl
# 10 serial
# 5 series
# 10 serious
# 4 serpentine
# 5 serv
# 10 server
# 342 service
# 13 serviced
# 164 servicenow
# 136 services
# 185 set
# 13 sets
# 21 setting
# 9 settings
# 4 setup
# 4 seventh
# 145 several
# 5 severe
# 68 sewage
# 38 sewer
# 41 sh
# 31 shade
# 4 shades
# 16 shaft
# 6 shahin
# 5 shaking
# 4 shall
# 7 shampoo
# 4 shampooing
# 7 shape
# 8 shaped
# 8 sharalyn
# 36 shared
# 14 shattered
# 6 shaun
# 5 sheave
# 7 shed
# 13 sheet
# 6 sheets
# 9 shelby
# 29 shelf
# 4 shell
# 18 shelves
# 18 shelving
# 52 shesc
# 6 shift
# 12 shirin
# 5 shoes
# 8 shoot
# 492 shop
# 27 shops
# 15 short
# 5 shorted
# 26 show
# 496 shower
# 4 showerhead
# 7 showering
# 12 showers
# 20 showing
# 5 shown
# 6 shows
# 164 shut
# 39 shutdown
# 7 shutdowns
# 21 shutting
# 5 sick
# 518 side
# 15 sides
# 19 sidewalk
# 4 sierra
# 4 sight
# 216 sign
# 19 signage
# 6 signal
# 6 signed
# 8 significant
# 4 significantly
# 40 signs
# 4 sill
# 6 silver
# 18 sim
# 7 similar
# 5 simon
# 12 simone
# 9 simpson
# 171 since
# 4 sincerely
# 22 single
# 718 sink
# 65 sinks
# 10 sit
# 26 site
# 14 sitting
# 15 situation
# 7 six
# 10 sixth
# 28 size
# 10 sized
# 4 sizow
# 16 skd
# 4 skid
# 5 slammed
# 12 slamming
# 11 slams
# 17 sleep
# 7 sleeping
# 15 slide
# 32 sliding
# 12 slightly
# 7 slip
# 6 sloan
# 4 slots
# 59 slow
# 50 slowly
# 120 small
# 12 smaller
# 9 smart
# 5 smashed
# 109 smell
# 10 smelled
# 8 smelling
# 45 smells
# 23 smith
# 95 smoke
# 6 smoking
# 6 smoothly
# 13 snake
# 11 snaked
# 5 snapped
# 17 snowberger
# 11 soaked
# 9 soaking
# 45 soap
# 5 soccer
# 22 social
# 16 socket
# 9 sockets
# 7 soda
# 3 soffit
# 10 sofia
# 4 softball
# 52 softener
# 4 soil
# 42 sol
# 6 solange
# 16 solar
# 8 sols
# 7 solution
# 4 solutions
# 4 solve
# 4 solvent
# 16 somebody
# 8 somehow
# 589 someone
# 91 something
# 8 sometime
# 26 sometimes
# 6 somewhat
# 10 somewhere
# 101 sonora
# 174 soon
# 7 sooner
# 14 sorry
# 12 sort
# 4 sosias
# 40 sound
# 9 sounding
# 17 sounds
# 27 source
# 287 south
# 14 southeast
# 10 southern
# 4 southside
# 31 southwest
# 216 space
# 29 spaces
# 7 spare
# 3 sparked
# 4 sparking
# 12 sparky
# 3 speakers
# 38 special
# 3 specialist
# 6 specific
# 7 specifically
# 3 specified
# 3 specs
# 6 speed
# 8 spencer
# 10 spider
# 10 spiders
# 3 spigot
# 3 spigots
# 3 spikes
# 16 spill
# 18 spilled
# 7 spilling
# 5 spin
# 8 spins
# 3 splash
# 14 split
# 46 spoke
# 3 spool
# 4 sports
# 33 spot
# 18 spots
# 4 spotted
# 5 spout
# 3 sprau
# 69 spray
# 34 sprayed
# 23 spraying
# 7 sprays
# 4 spread
# 5 spreading
# 24 spring
# 106 sprinkler
# 25 sprinklers
# 3 spud
# 10 square
# 5 squares
# 14 squeaking
# 5 squeaks
# 5 squeaky
# 3 squealing
# 7 sr
# 37 ss
# 70 ssv
# 301 st
# 3 stabilize
# 5 stacey
# 3 stacked
# 3 stacy
# 7 stad
# 16 stadium
# 3 staefa
# 177 staff
# 27 stage
# 30 stain
# 56 stained
# 5 stainless
# 56 stains
# 55 stair
# 16 staircase
# 43 stairs
# 25 stairway
# 126 stairwell
# 18 stairwells
# 4 stake
# 206 stall
# 34 stalls
# 18 stan
# 24 stand
# 17 standard
# 12 standby
# 28 standing
# 5 stands
# 45 starbucks
# 84 start
# 48 started
# 7 starter
# 53 starting
# 8 starts
# 4 stat
# 28 state
# 24 stated
# 18 states
# 9 static
# 16 stating
# 38 station
# 17 stations
# 30 status
# 22 stauf
# 28 stauffer
# 34 stay
# 13 staying
# 11 stays
# 4 ste
# 6 steadily
# 17 steady
# 54 steam
# 7 steel
# 11 steering
# 6 stem
# 5 stems
# 5 stench
# 10 step
# 20 stephanie
# 13 stephen
# 7 stephens
# 6 steps
# 33 stetka
# 39 steve
# 28 steven
# 4 stevens
# 11 stewart
# 11 stick
# 4 sticker
# 39 sticking
# 22 sticks
# 16 sticky
# 231 still
# 22 stock
# 8 stolen
# 3 stool
# 4 stools
# 126 stop
# 72 stopped
# 24 stopper
# 5 stopping
# 12 stops
# 77 storage
# 28 store
# 9 stored
# 28 storm
# 5 storms
# 56 stove
# 4 str
# 3 straight
# 4 straighten
# 45 strainer
# 8 strange
# 18 strayhorne
# 11 stream
# 27 street
# 14 strike
# 5 string
# 11 strip
# 15 stripped
# 10 stripping
# 31 strong
# 28 structure
# 203 stuck
# 305 student
# 102 students
# 7 studies
# 9 studio
# 50 study
# 8 stuff
# 12 stuffy
# 5 stump
# 8 style
# 17 sub
# 56 subject
# 22 submit
# 220 submitted
# 11 submitting
# 9 substance
# 4 subway
# 4 suddenly
# 3 sue
# 4 suggested
# 140 suite
# 5 suitemates
# 18 suites
# 4 sullivan
# 23 summer
# 80 sump
# 38 sun
# 52 sunday
# 5 sunrise
# 11 sunset
# 6 super
# 4 supervision
# 16 supervisor
# 4 supervisory
# 3 supplied
# 10 supplies
# 65 supply
# 46 support
# 4 suppose
# 18 supposed
# 9 suppression
# 136 sure
# 4 surface
# 4 surfaces
# 10 surplus
# 16 surrounding
# 27 susan
# 10 susana
# 4 suspect
# 12 sutton
# 7 suzanne
# 25 sw
# 50 swan
# 6 swann
# 10 swap
# 5 swarm
# 5 swarming
# 16 swartz
# 4 sweat
# 25 sweep
# 4 sweeper
# 6 swenson
# 17 swept
# 29 swimming
# 5 swing
# 3 swinging
# 4 swipe
# 5 swiss
# 98 switch
# 6 switched
# 11 switches
# 487 swo
# 3 syfritt
# 4 synthetic
# 218 system
# 29 systems
# 67 table
# 47 tables
# 15 tabling
# 7 tack
# 16 tag
# 12 tagged
# 6 tags
# 3 tahlia
# 4 tail
# 3 takako
# 200 take
# 46 taken
# 29 takes
# 31 taking
# 3 talia
# 9 talk
# 8 talked
# 10 tall
# 10 talon
# 5 tameka
# 4 tamera
# 13 tami
# 7 tammarra
# 4 tammy
# 77 tank
# 54 tanner
# 48 tannous
# 12 tap
# 30 tape
# 5 taped
# 4 tara
# 339 task
# 31 taylor
# 7 tbd
# 4 teach
# 8 teachers
# 10 teaching
# 4 teague
# 31 team
# 15 tear
# 4 tebbe
# 159 tech
# 6 technical
# 19 technician
# 9 technology
# 16 techs
# 6 ted
# 4 tel
# 4 telephone
# 4 television
# 10 tell
# 70 temp
# 81 tempe
# 248 temperature
# 24 temperatures
# 11 temporarily
# 17 temporary
# 17 temps
# 7 ten
# 4 tenants
# 5 termite
# 7 termites
# 11 terrible
# 9 terripin
# 4 terry
# 58 test
# 29 tested
# 68 testing
# 4 text
# 5 tf
# 405 th
# 6 tha
# 1708 thank
# 682 thanks
# 13 theater
# 6 theatre
# 12 therefore
# 10 theresa
# 4 thermo
# 15 thermography
# 4 thermometer
# 78 thermostat
# 4 thick
# 34 thing
# 18 things
# 78 think
# 5 thinks
# 106 third
# 13 thomas
# 15 thompson
# 6 thor
# 8 thoroughly
# 36 though
# 17 thought
# 76 three
# 24 threshold
# 68 throughout
# 5 throw
# 4 throwing
# 7 thrown
# 21 thru
# 5 thurs
# 31 thursday
# 7 thus
# 9 thx
# 34 thyssen
# 5 thyssenkrupp
# 11 ti
# 24 tibbetts
# 31 ticket
# 4 tie
# 7 tight
# 17 tighten
# 18 tightened
# 159 tile
# 142 tiles
# 39 tim
# 8 timberman
# 834 time
# 7 timer
# 71 times
# 4 timing
# 4 timothy
# 8 tina
# 4 tiny
# 5 tip
# 28 tire
# 44 tires
# 25 title
# 4 tiziana
# 9 tj
# 10 tl
# 40 tma
# 13 tmp
# 24 tmpe
# 3 tn
# 5 toc
# 49 tod
# 138 today
# 4 todd
# 17 together
# 878 toilet
# 57 toilets
# 47 told
# 3 toliet
# 25 tom
# 4 tomi
# 12 tommy
# 115 tomorrow
# 9 toni
# 27 tonight
# 63 tony
# 18 took
# 16 tool
# 11 tools
# 135 top
# 9 tops
# 15 torn
# 13 torres
# 119 total
# 6 totally
# 53 touch
# 13 tour
# 5 toward
# 13 towards
# 4 towed
# 68 towel
# 48 towels
# 132 tower
# 153 towers
# 4 town
# 7 townsend
# 5 towry
# 10 tr
# 45 track
# 7 tracks
# 30 tracy
# 4 traffic
# 4 trail
# 22 training
# 5 tran
# 3 trans
# 664 transfer
# 13 transferred
# 4 transferring
# 9 transformer
# 4 transit
# 8 transition
# 3 transmission
# 130 trap
# 8 trapped
# 28 traps
# 209 trash
# 3 trashcan
# 13 tray
# 5 trays
# 21 treat
# 5 treated
# 212 treatment
# 67 tree
# 24 trees
# 4 trent
# 4 tresz
# 91 tried
# 5 tries
# 19 trim
# 6 trimmed
# 5 trimming
# 10 trip
# 22 tripped
# 11 tripping
# 4 trips
# 59 trouble
# 24 troubleshoot
# 25 truck
# 19 truly
# 30 try
# 24 trying
# 53 ts
# 66 tub
# 18 tube
# 10 tubes
# 3 tubing
# 4 tues
# 40 tuesday
# 30 tunnel
# 10 turf
# 1488 turn
# 145 turned
# 38 turning
# 16 turns
# 7 tutoring
# 36 tv
# 11 twice
# 5 twin
# 322 two
# 16 tyler
# 50 type
# 4 tyrone
# 3 uasb
# 5 uc
# 29 ucb
# 10 ucc
# 18 uccpoly
# 60 ucent
# 6 uclub
# 16 um
# 4 un
# 65 unable
# 5 unattached
# 5 unbearable
# 6 unbearably
# 50 unclog
# 21 unclogged
# 8 unclogging
# 12 uncomfortable
# 12 uncomfortably
# 7 unctra
# 9 unctrb
# 9 unctrc
# 5 undergraduate
# 3 underground
# 51 underneath
# 5 understand
# 5 uneven
# 5 unfortunately
# 4 unger
# 37 union
# 6 unisex
# 284 unit
# 35 units
# 4 univ
# 214 university
# 4 univt
# 18 unknown
# 10 unless
# 74 unlock
# 41 unlocked
# 10 unlocking
# 5 unpleasant
# 4 unplug
# 7 unplugged
# 5 unresponsive
# 3 unsafe
# 6 unstable
# 13 unsure
# 10 unusable
# 6 unusually
# 36 update
# 9 updated
# 9 upgrade
# 50 upon
# 28 upper
# 13 ups
# 26 upsi
# 12 upstairs
# 4 urban
# 72 urgent
# 15 urgently
# 176 urinal
# 46 urinals
# 6 urine
# 84 us
# 4 usable
# 4 usage
# 118 usb
# 219 use
# 85 used
# 62 using
# 4 usual
# 12 usually
# 16 utility
# 7 utilized
# 8 uto
# 4 utowers
# 9 vac
# 16 vacant
# 7 vacated
# 4 vacation
# 82 vacuum
# 38 vacuumed
# 12 vacuuming
# 11 valance
# 4 valenti
# 4 valerie
# 202 valve
# 150 valves
# 14 valwood
# 31 van
# 3 vance
# 20 vandalism
# 3 vandalized
# 24 vanity
# 9 variable
# 13 various
# 33 vasquez
# 6 vaughn
# 11 vault
# 4 vbd
# 4 vct
# 8 vdd
# 5 vedral
# 381 vehicle
# 6 vehicles
# 3 velazquez
# 4 venable
# 4 vending
# 25 vendor
# 3 vendors
# 91 vent
# 5 ventana
# 18 ventilation
# 52 vents
# 9 verbena
# 118 verde
# 3 verified
# 12 verify
# 8 veronica
# 4 vertical
# 4 vesna
# 3 vestibule
# 4 veterans
# 124 vfd
# 11 vg
# 12 via
# 4 vibration
# 4 victor
# 4 view
# 7 villa
# 7 village
# 9 villas
# 8 vinyl
# 27 violation
# 45 visa
# 4 visible
# 7 visit
# 6 visiting
# 4 visitors
# 70 vista
# 6 vistadelsoldesk
# 4 vivarium
# 11 vj
# 6 vm
# 7 vn
# 5 voelz
# 9 voicemail
# 4 volt
# 10 voltage
# 25 vomit
# 18 vujs
# 5 wa
# 5 wabby
# 74 wait
# 15 waiting
# 111 walk
# 6 walked
# 11 walking
# 4 walkthrough
# 17 walkway
# 763 wall
# 101 walls
# 7 wand
# 11 wann
# 56 want
# 19 wanted
# 18 wants
# 6 wardrobe
# 36 warehouse
# 159 warm
# 14 warmer
# 12 warranty
# 44 wash
# 6 washed
# 66 washer
# 7 washers
# 48 washing
# 6 wasp
# 4 wasps
# 21 waste
# 10 wasting
# 9 watch
# 1774 water
# 10 watt
# 13 wax
# 172 way
# 5 wayne
# 5 wb
# 4 wc
# 9 wd
# 9 weak
# 5 wear
# 15 weather
# 12 weatherup
# 43 wednesday
# 7 weeds
# 130 week
# 60 weekend
# 6 weekends
# 472 weekly
# 66 weeks
# 8 wei
# 5 weight
# 13 weird
# 5 welcome
# 8 weld
# 5 welded
# 15 welder
# 8 welding
# 160 well
# 19 wells
# 12 wendell
# 89 went
# 9 werner
# 4 wesley
# 445 west
# 59 wet
# 20 wexler
# 71 wfa
# 8 wghl
# 9 wh
# 15 whall
# 10 whatever
# 19 wheel
# 4 wheelchair
# 7 wheels
# 17 whenever
# 14 whether
# 76 white
# 57 whiteboard
# 12 whiteboards
# 37 whole
# 4 wi
# 12 wide
# 22 wielert
# 4 wife
# 26 wifi
# 5 wii
# 4 wilkins
# 7 william
# 8 williams
# 6 willow
# 9 wilsn
# 31 wilson
# 22 win
# 10 wind
# 226 window
# 29 windows
# 5 windshield
# 67 wing
# 6 wings
# 10 winter
# 11 wipe
# 7 wiped
# 9 wiper
# 20 wire
# 14 wired
# 8 wireless
# 33 wires
# 20 wiring
# 4 wish
# 45 within
# 51 without
# 3 witnessed
# 8 wittmann
# 19 wnenta
# 177 wo
# 5 wobbly
# 4 woke
# 10 woman
# 196 women
# 20 womens
# 32 wondering
# 24 wont
# 27 wood
# 8 wooden
# 7 woods
# 805 work
# 27 worked
# 16 worker
# 14 workers
# 787 working
# 55 works
# 4 workshop
# 4 workstations
# 12 worn
# 10 worried
# 25 worse
# 514 would
# 92 wozniak
# 4 wp
# 6 wpc
# 5 wrestling
# 30 wrigley
# 7 writing
# 30 wrong
# 38 wrr
# 4 ws
# 4 wuc
# 6 wurster
# 15 wxlr
# 3 xb
# 20 xbox
# 8 xc
# 3 xd
# 19 yahoo
# 5 yang
# 24 yard
# 37 year
# 7 years
# 19 yellow
# 22 yes
# 51 yesterday
# 28 yet
# 129 yg
# 4 yi
# 4 yo
# 14 young
# 5 zach
# 3 zack
# 22 zaller
# 5 zambrano
# 6 zhang
# 4 zheng
# 8 zoltan
# 18 zone
# 7 zones
# 9 zoraya

# %% [markdown]
# ### Random Forest

# %%
print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100, max_features=70) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable

forest1 = forest.fit( train_data_features, train["WO"] )

forest2 = forest.fit(train_data_features, train["WOPriority"])
# Out:
# Training the random forest...

# %% [markdown]
# ### Making predictions on the test set

# %%
# Read the test data
test = pd.read_csv("E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/test.csv", header=0, encoding="cp1252", low_memory=False)

# %%
print(test.shape)
# Out:
# (8055, 7)

# %%
# Create an empty list and append the clean requests one by one
num_requests = len(test["ActionRequested"])
clean_test_requests = []

# %%
print("Cleaning and parsing the test set maintenance requests...\n")
for i in range(0,num_requests):
    clean_requests = maintenance( test["ActionRequested"][i] )
    clean_test_requests.append( clean_requests )
# Out:
# Cleaning and parsing the test set maintenance requests...

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_requests)
test_data_features = test_data_features.toarray()

# %%
##tedf = pd.DataFrame(test_data_features)
##tedf.to_csv("E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/wordvectorstest.csv")

# %%
#Obtaining predictions by cross-validation
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

# %%
#Performing 10 fold cross-validation on the data
predicted1 = cross_val_predict(forest1, train_data_features, train["WO"], cv=10)
metrics.accuracy_score(train["WO"], predicted1)
# Out:
# 0.84213580963435863

# %%
#Performing 10 fold cross-validation on the data
predicted2 = cross_val_predict(forest2, train_data_features, train["WOPriority"], cv=10)
metrics.accuracy_score(train["WOPriority"], predicted2)
# Out:
# 0.80494292899980657

# %%
# Use the random forest to make predictions for work order types and priorities of requests
result1 = forest1.predict(test_data_features)
result2 = forest2.predict(test_data_features)

# %%
# Copy the results to a pandas dataframe 
output1 = pd.DataFrame( data={"id":test["WorkOrder"], "Predicted_WO":result1, "Actual_WO":test["WO"] } )
output2 = pd.DataFrame( data={"id":test["WorkOrder"], "Predicted_Priority":result2, "Actual_Priority":test["WOPriority"]} )

# %%
# Use pandas to write the comma-separated output file
output1.to_csv( "E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/TestSetPredictions/WOtypes.csv", index=False, quoting=3 )
output2.to_csv( "E:/ASU Energy Leadership Informatics/neptune files/Maintenance Requests/TestSetPredictions/Prioritytypes.csv", index=False, quoting=3 )
